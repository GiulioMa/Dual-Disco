# %%
import os
import pickle

data_folder = "./Data"
file_path = os.path.join(data_folder, "pytorch_database.pkl")

with open(file_path, "rb") as f:
    loaded_data = pickle.load(f)

# %%
loaded_data.keys()
# Out:
# dict_keys(['seq_tensor', 'sim_tensor', 'file_names', 'mode_descriptions'])

# %%
loaded_data['mode_descriptions'][124]
# Out:
# ('Keyhole2', 'Conduction2')

# %%
# Modes for testing
test_modes = [
    ('Conduction2', 'Conduction2'),
    ('Conduction2', 'Keyhole2'),
    ('Keyhole2', 'Conduction2'),
    ('Keyhole2', 'Keyhole2'),
]

# %%
mode_descriptions = loaded_data['mode_descriptions']
# Identify indexes for test data
test_indexes = [i for i, mode in enumerate(mode_descriptions) if mode in test_modes]

# %%
# Identify indexes for train data
total_indexes = set(range(len(mode_descriptions)))
train_indexes = list(total_indexes - set(test_indexes))

# Function to extract sub-tensors based on indexes
def extract_sub_tensors(tensor, indexes):
    return tensor[indexes]

# Allocate data to train and test dictionaries
train_data = {
    "seq_tensor": extract_sub_tensors(loaded_data["seq_tensor"], train_indexes),
    "sim_tensor": extract_sub_tensors(loaded_data["sim_tensor"], train_indexes),
    "file_names": [loaded_data["file_names"][i] for i in train_indexes],
    "mode_descriptions": [loaded_data["mode_descriptions"][i] for i in train_indexes],
}

test_data = {
    "seq_tensor": extract_sub_tensors(loaded_data["seq_tensor"], test_indexes),
    "sim_tensor": extract_sub_tensors(loaded_data["sim_tensor"], test_indexes),
    "file_names": [loaded_data["file_names"][i] for i in test_indexes],
    "mode_descriptions": [loaded_data["mode_descriptions"][i] for i in test_indexes],
}

# %%
# Function to print file names and modes for a given dataset
def print_file_info(dataset, dataset_name):
    print(f"Files in {dataset_name}:")
    for file_name, mode in zip(dataset["file_names"], dataset["mode_descriptions"]):
        print(f"File Name: {file_name}, Mode: {mode}")
    print("\n")

# %%
# Loop over all files in the train set
print_file_info(train_data, "Train Data")
# Out:
# Files in Train Data:
# File Name: ('File_0', 'File_10'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_1', 'File_11'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_2', 'File_12'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_3', 'File_13'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_4', 'File_14'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_5', 'File_15'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_6', 'File_16'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_7', 'File_17'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_8', 'File_18'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_9', 'File_19'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_20', 'File_30'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_21', 'File_31'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_22', 'File_32'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_23', 'File_33'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_24', 'File_34'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_25', 'File_35'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_26', 'File_36'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_27', 'File_37'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_28', 'File_38'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_29', 'File_39'), Mode: ('Conduction 2', 'Conduction 2')
# File Name: ('File_40', 'File_55'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_41', 'File_56'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_42', 'File_57'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_43', 'File_58'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_44', 'File_59'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_45', 'File_60'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_46', 'File_61'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_47', 'File_62'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_48', 'File_63'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_49', 'File_64'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_50', 'File_65'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_51', 'File_66'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_52', 'File_67'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_53', 'File_68'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_54', 'File_69'), Mode: ('Conduction1', 'Conduction1')
# File Name: ('File_100', 'File_115'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_101', 'File_116'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_102', 'File_117'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_103', 'File_118'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_104', 'File_119'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_105', 'File_120'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_106', 'File_121'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_107', 'File_122'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_108', 'File_123'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_109', 'File_124'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_110', 'File_125'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_111', 'File_126'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_112', 'File_127'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_113', 'File_128'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_114', 'File_129'), Mode: ('Conduction3', 'Conduction3')
# File Name: ('File_130', 'File_145'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_131', 'File_146'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_132', 'File_147'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_133', 'File_148'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_134', 'File_149'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_135', 'File_150'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_136', 'File_151'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_137', 'File_152'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_138', 'File_153'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_139', 'File_154'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_140', 'File_155'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_141', 'File_156'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_142', 'File_157'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_143', 'File_158'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_144', 'File_159'), Mode: ('Conduction1', 'Keyhole1')
# File Name: ('File_160', 'File_175'), Mode: ('Keyhole1', 'Conduction1')
# File Name: ('File_161', 'File_176'), Mode: ('Keyhole1', 'Conduction1')
# File Name: ('File_162', 'File_177'), Mode: ('Keyhole1', 'Conduction1')
# File Name: ('File_163', 'File_178'), Mode: ('Keyhole1', 'Conduction1')
# File Name: ('File