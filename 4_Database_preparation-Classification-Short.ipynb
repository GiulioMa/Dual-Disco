# %%
import pickle

file_name = 'my_dic.pkl'
    
# Open the file and load its content
with open(file_name, 'rb') as file:
    data_dict = pickle.load(file)
    
# Print all the keys
print("Combined dictionary keys:", len(data_dict.keys()))
# Out:
# Combined dictionary keys: 400

# %%
data_dict.keys()
# Out:
# dict_keys(['File_0', 'File_1', 'File_2', 'File_3', 'File_4', 'File_5', 'File_6', 'File_7', 'File_8', 'File_9', 'File_10', 'File_11', 'File_12', 'File_13', 'File_14', 'File_15', 'File_16', 'File_17', 'File_18', 'File_19', 'File_20', 'File_21', 'File_22', 'File_23', 'File_24', 'File_25', 'File_26', 'File_27', 'File_28', 'File_29', 'File_30', 'File_31', 'File_32', 'File_33', 'File_34', 'File_35', 'File_36', 'File_37', 'File_38', 'File_39', 'File_40', 'File_41', 'File_42', 'File_43', 'File_44', 'File_45', 'File_46', 'File_47', 'File_48', 'File_49', 'File_50', 'File_51', 'File_52', 'File_53', 'File_54', 'File_55', 'File_56', 'File_57', 'File_58', 'File_59', 'File_60', 'File_61', 'File_62', 'File_63', 'File_64', 'File_65', 'File_66', 'File_67', 'File_68', 'File_69', 'File_70', 'File_71', 'File_72', 'File_73', 'File_74', 'File_75', 'File_76', 'File_77', 'File_78', 'File_79', 'File_80', 'File_81', 'File_82', 'File_83', 'File_84', 'File_85', 'File_86', 'File_87', 'File_88', 'File_89', 'File_90', 'File_91', 'File_92', 'File_93', 'File_94', 'File_95', 'File_96', 'File_97', 'File_98', 'File_99', 'File_100', 'File_101', 'File_102', 'File_103', 'File_104', 'File_105', 'File_106', 'File_107', 'File_108', 'File_109', 'File_110', 'File_111', 'File_112', 'File_113', 'File_114', 'File_115', 'File_116', 'File_117', 'File_118', 'File_119', 'File_120', 'File_121', 'File_122', 'File_123', 'File_124', 'File_125', 'File_126', 'File_127', 'File_128', 'File_129', 'File_130', 'File_131', 'File_132', 'File_133', 'File_134', 'File_135', 'File_136', 'File_137', 'File_138', 'File_139', 'File_140', 'File_141', 'File_142', 'File_143', 'File_144', 'File_145', 'File_146', 'File_147', 'File_148', 'File_149', 'File_150', 'File_151', 'File_152', 'File_153', 'File_154', 'File_155', 'File_156', 'File_157', 'File_158', 'File_159', 'File_160', 'File_161', 'File_162', 'File_163', 'File_164', 'File_165', 'File_166', 'File_167', 'File_168', 'File_169', 'File_170', 'File_171', 'File_172', 'File_173', 'File_174', 'File_175', 'File_176', 'File_177', 'File_178', 'File_179', 'File_180', 'File_181', 'File_182', 'File_183', 'File_184', 'File_185', 'File_186', 'File_187', 'File_188', 'File_189', 'File_190', 'File_191', 'File_192', 'File_193', 'File_194', 'File_195', 'File_196', 'File_197', 'File_198', 'File_199', 'File_200', 'File_201', 'File_202', 'File_203', 'File_204', 'File_205', 'File_206', 'File_207', 'File_208', 'File_209', 'File_210', 'File_211', 'File_212', 'File_213', 'File_214', 'File_215', 'File_216', 'File_217', 'File_218', 'File_219', 'File_220', 'File_221', 'File_222', 'File_223', 'File_224', 'File_225', 'File_226', 'File_227', 'File_228', 'File_229', 'File_230', 'File_231', 'File_232', 'File_233', 'File_234', 'File_235', 'File_236', 'File_237', 'File_238', 'File_239', 'File_240', 'File_241', 'File_242', 'File_243', 'File_244', 'File_245', 'File_246', 'File_247', 'File_248', 'File_249', 'File_250', 'File_251', 'File_252', 'File_253', 'File_254', 'File_255', 'File_256', 'File_257', 'File_258', 'File_259', 'File_260', 'File_261', 'File_262', 'File_263', 'File_264', 'File_265', 'File_266', 'File_267', 'File_268', 'File_269', 'File_270', 'File_271', 'File_272', 'File_273', 'File_274', 'File_275', 'File_276', 'File_277', 'File_278', 'File_279', 'File_280', 'File_281', 'File_282', 'File_283', 'File_284', 'File_285', 'File_286', 'File_287', 'File_288', 'File_289', 'File_290', 'File_291', 'File_292', 'File_293', 'File_294', 'File_295', 'File_296', 'File_297', 'File_298', 'File_299', 'File_300', 'File_301', 'File_302', 'File_303', 'File_304', 'File_305', 'File_306', 'File_307', 'File_308', 'File_309', 'File_310', 'File_311', 'File_312', 'File_313', 'File_314', 'File_315', 'File_316', 'File_317', 'File_318', 'File_319', 'File_320', 'File_321', 'File_322', 'File_323', 'File_324', 'File_325', 'File_326', 'File_327', 'File_328', 'File_329', 'File_330', 'File_331', 'File_332', 'File_333', 'File_334', 'File_335', 'File_336', 'File_337', 'File_338', 'File_339', 'File_340', 'File_3 ...

# %%
data_dict['File_144']
# Out:
# {'Channel_1': {'Operation': 'Sequential',
#   'Cube 1 Mode': 'Conduction1',
#   'Cube 2 Mode': 'Keyhole1',
#   'segments': [array([ 1.881256 ,  0.4908752, -2.017059 , ...,  1.261749 ,  2.152557 ,
#            1.882172 ]),
#    array([ 1.717224 ,  1.48407  ,  0.771637 , ..., -0.1409912,  0.6596375,
#            1.547241 ])],
#   'boundaries': (array([ 19557, 706880]), array([ 502985, 1377629])),
#   'avg_length': 577089.5,
#   'std_dev': 93660.5,
#   'num_segments': 2},
#  'Channel_2': {'Operation': 'Sequential',
#   'Cube 1 Mode': 'Conduction1',
#   'Cube 2 Mode': 'Keyhole1',
#   'segments': [array([ 1.628876 ,  1.441345 , -1.601868 , ...,  0.3134155,  1.319427 ,
#            1.571503 ]),
#    array([1.58432  , 1.397705 , 1.246338 , ..., 0.4893494, 1.133118 ,
#           1.5625   ])],
#   'boundaries': (array([ 19537, 706735]), array([ 501810, 1376337])),
#   'avg_length': 575938.5,
#   'std_dev': 93664.5,
#   'num_segments': 2},
#  'Channel_3': {'Operation': 'Sequential',
#   'Cube 1 Mode': 'Conduction1',
#   'Cube 2 Mode': 'Keyhole1',
#   'segments': [array([ 0.00610352,  0.00488281, -0.00457764, ..., -0.01205444,
#            0.00549316,  0.01678467]),
#    array([-0.02319336,  0.00183106,  0.03173828, ..., -0.00152588,
#            0.00976562,  0.01220703])],
#   'boundaries': (array([ 19537, 706735]), array([ 501810, 1376337])),
#   'avg_length': 575938.5,
#   'std_dev': 93664.5,
#   'num_segments': 2}}

# %%
sequential_dict = {}
simultaneous_dict = {}

# Loop over all files
for file_name, file_data in data_dict.items():
    print(f"Processing {file_name}...")
    for channel_name, channel_data in file_data.items():

        segments = channel_data['segments']
        mode1 = channel_data['Cube 1 Mode']
        mode2 = channel_data['Cube 2 Mode']

        # Check operation type and update the respective dictionary
        if channel_data['Operation'] == 'Sequential':
            if file_name not in sequential_dict:
                sequential_dict[file_name] = {'Cube 1 Mode': mode1, 'Cube 2 Mode': mode2, 'channels': {}}
            
            # Only update channel specific data under the 'channels' sub-dictionary
            sequential_dict[file_name]['channels'][channel_name] = {'segment': segments}

        elif channel_data['Operation'] == 'Simultaneous':
            if file_name not in simultaneous_dict:
                simultaneous_dict[file_name] = {'Cube 1 Mode': mode1, 'Cube 2 Mode': mode2, 'channels': {}}
            
            # Only update channel specific data under the 'channels' sub-dictionary
            simultaneous_dict[file_name]['channels'][channel_name] = {'segment': segments}
# Out:
# Processing File_0...
# Processing File_1...
# Processing File_2...
# Processing File_3...
# Processing File_4...
# Processing File_5...
# Processing File_6...
# Processing File_7...
# Processing File_8...
# Processing File_9...
# Processing File_10...
# Processing File_11...
# Processing File_12...
# Processing File_13...
# Processing File_14...
# Processing File_15...
# Processing File_16...
# Processing File_17...
# Processing File_18...
# Processing File_19...
# Processing File_20...
# Processing File_21...
# Processing File_22...
# Processing File_23...
# Processing File_24...
# Processing File_25...
# Processing File_26...
# Processing File_27...
# Processing File_28...
# Processing File_29...
# Processing File_30...
# Processing File_31...
# Processing File_32...
# Processing File_33...
# Processing File_34...
# Processing File_35...
# Processing File_36...
# Processing File_37...
# Processing File_38...
# Processing File_39...
# Processing File_40...
# Processing File_41...
# Processing File_42...
# Processing File_43...
# Processing File_44...
# Processing File_45...
# Processing File_46...
# Processing File_47...
# Processing File_48...
# Processing File_49...
# Processing File_50...
# Processing File_51...
# Processing File_52...
# Processing File_53...
# Processing File_54...
# Processing File_55...
# Processing File_56...
# Processing File_57...
# Processing File_58...
# Processing File_59...
# Processing File_60...
# Processing File_61...
# Processing File_62...
# Processing File_63...
# Processing File_64...
# Processing File_65...
# Processing File_66...
# Processing File_67...
# Processing File_68...
# Processing File_69...
# Processing File_70...
# Processing File_71...
# Processing File_72...
# Processing File_73...
# Processing File_74...
# Processing File_75...
# Processing File_76...
# Processing File_77...
# Processing File_78...
# Processing File_79...
# Processing File_80...
# Processing File_81...
# Processing File_82...
# Processing File_83...
# Processing File_84...
# Processing File_85...
# Processing File_86...
# Processing File_87...
# Processing File_88...
# Processing File_89...
# Processing File_90...
# Processing File_91...
# Processing File_92...
# Processing File_93...
# Processing File_94...
# Processing File_95...
# Processing File_96...
# Processing File_97...
# Processing File_98...
# Processing File_99...
# Processing File_100...
# Processing File_101...
# Processing File_102...
# Processing File_103...
# Processing File_104...
# Processing File_105...
# Processing File_106...
# Processing File_107...
# Processing File_108...
# Processing File_109...
# Processing File_110...
# Processing File_111...
# Processing File_112...
# Processing File_113...
# Processing File_114...
# Processing File_115...
# Processing File_116...
# Processing File_117...
# Processing File_118...
# Processing File_119...
# Processing File_120...
# Processing File_121...
# Processing File_122...
# Processing File_123...
# Processing File_124...
# Processing File_125...
# Processing File_126...
# Processing File_127...
# Processing File_128...
# Processing File_129...
# Processing File_130...
# Processing File_131...
# Processing File_132...
# Processing File_133...
# Processing File_134...
# Processing File_135...
# Processing File_136...
# Processing File_137...
# Processing File_138...
# Processing File_139...
# Processing File_140...
# Processing File_141...
# Processing File_142...
# Processing File_143...
# Processing File_144...
# Processing File_145...
# Processing File_146...
# Processing File_147...
# Processing File_148...
# Processing File_149...
# Processing File_150...
# Processing File_151...
# Processing File_152...
# Processing File_153...
# Processing File_154...
# Processing File_155...
# Processing File_156...
# Processing File_157...
# Processing File_158...
# Processing File_159...
# Processing File_160...
# Processing File_161...
# Processing File_162...
# Processing File_163...
# Processing File_164...
# Processing File_165...
# Processing File_166...
# Processing File_167...
# Processing File_168...
# Processing File_169...
# Processing File_170...
# Processing File_171...
# Processing File_172...
# Processing File_173...
# Processing File_174...
# Processing File_175...
# Processing File_176...
# Processing File_177...
# Processing File_178...
# Processing File_179...
# Processing File_180...
# Processing File_181...
# Processing File_182...
# Processing File_183...
# Processing File_184...
# Processing File_185...
# Processing File_186...
# Processing File_187...
# Processing File_188...
# Processing File_189...
# Processing File_190...
# Processing File_191...
# Processing File_192...
# Processing File_193...
# Processing File_194...
# Processing File_195...
# Processing File_196...
# Processing File_197...
# Processing File_198...
# Processing File_199...
# Processing File_200...
# Processing File_201...
# Processing File_202...
# Processing File_203...
# Processing File_204...
# Processing File_205...
# Processing File_206...
# Processing File_207...
# Processing File_208...
# Processing File_209...
# Processing File_210...
# Processing File_211...
# Processing File_212...
# Processing File_213...
# Processing File_214...
# Processing File_215...
# Processing File_216...
# Processing File_217...
# Processing File_218...
# Processing File_219...
# Processing File_220...
# Processing File_221...
# Processing File_222...
# Processing File_223...
# Processing File_224...
# Processing File_225...
# Processing File_226...
# Processing File_227...
# Processing File_228...
# Processing File_229...
# Processing File_230...
# Processing File_231...
# Processing File_232...
# Processing File_233...
# Processing File_234...
# Processing File_235...
# Processing File_236...
# Processing File_237...
# Processing File_238...
# Processing File_239...
# Processing File_240...
# Processing File_241...
# Processing File_242...
# Processing File_243...
# Processing File_244...
# Processing File_245...
# Processing File_246...
# Processing File_247...
# Processing File_248...
# Processing File_249...
# Processing File_250...
# Processing File_251...
# Processing File_252...
# Processing File_253...
# Processing File_254...
# Processing File_255...
# Processing File_256...
# Processing File_257...
# Processing File_258...
# Processing File_259...
# Processing File_260...
# Processing File_261...
# Processing File_262...
# Processing File_263...
# Processing File_264...
# Processing File_265...
# Processing File_266...
# Processing File_267...
# Processing File_268...
# Processing File_269...
# Processing File_270...
# Processing File_271...
# Processing File_272...
# Processing File_273...
# Processing File_274...
# Processing File_275...
# Processing File_276...
# Processing File_277...
# Processing File_278...
# Processing File_279...
# Processing File_280...
# Processing File_281...
# Processing File_282...
# Processing File_283...
# Processing File_284...
# Processing File_285...
# Processing File_286...
# Processing File_287...
# Processing File_288...
# Processing File_289...
# Processing File_290...
# Processing File_291...
# Processing File_292...
# Processing File_293...
# Processing File_294...
# Processing File_295...
# Processing File_296...
# Processing File_297...
# Processing File_298...
# Processing File_299...
# Processing File_300...
# Processing File_301...
# Processing File_302...
# Processing File_303...
# Processing File_304...
# Processing File_305...
# Processing File_306...
# Processing File_307...
# Processing File_308...
# Processing File_309...
# Processing File_310...
# Processing File_311...
# Processing File_312...
# Processing File_313...
# Processing File_314...
# Processing File_315...
# Processing File_316...
# Processing File_317...
# Processing File_318...
# Processing File_319...
# Processing File_320...
# Processing File_321...
# Processing File_322...
# Processing File_323...
# Processing File_324...
# Processing File_325...
# Processing File_326...
# Processing File_327...
# Processing File_328...
# Processing File_329...
# Processing File_330...
# Processing File_331...
# Processing File_332...
# Processing File_333...
# Processing File_334...
# Processing File_335...
# Processing File_336...
# Processing File_337...
# Processing File_338...
# Processing File_339...
# Processing File_340...
# Processing File_341...
# Processing File_342...
# Processing File_343...
# Processing File_344...
# Processing File_345...
# Processing File_346...
# Processing File_347...
# Processing File_348...
# Processing File_349...
# Processing File_350...
# Processing File_351...
# Processing File_352...
# Processing File_353...
# Processing File_354...
# Processing File_355...
# Processing File_356...
# Processing File_357...
# Processing File_358...
# Processing File_359...
# Processing File_360...
# Processing File_361...
# Processing File_362...
# Processing File_363...
# Processing File_364...
# Processing File_365...
# Processing File_366...
# Processing File_367...
# Processing File_368...
# Processing File_369...
# Processing File_370...
# Processing File_371...
# Processing File_372...
# Processing File_373...
# Processing File_374...
# Processing File_375...
# Processing File_376...
# Processing File_377...
# Processing File_378...
# Processing File_379...
# Processing File_380...
# Processing File_381...
# Processing File_382...
# Processing File_383...
# Processing File_384...
# Processing File_385...
# Processing File_386...
# Processing File_387...
# Processing File_388...
# Processing File_389...
# Processing File_390...
# Processing File_391...
# Processing File_392...
# Processing File_393...
# Processing File_394...
# Processing File_395...
# Processing File_396...
# Processing File_397...
# Processing File_398...
# Processing File_399...

# %%
# Create iterators for both dictionaries
sequential_iter = iter(sequential_dict.items())
simultaneous_iter = iter(simultaneous_dict.items())

# Loop until we run out of items in either dictionary
while True:
    try:
        # Get the next item from both dictionaries
        seq_file, seq_data = next(sequential_iter)
        sim_file, sim_data = next(simultaneous_iter)

        # Compare Cube 1 Mode and Cube 2 Mode between the sequential and simultaneous file
        seq_mode1, seq_mode2 = seq_data['Cube 1 Mode'], seq_data['Cube 2 Mode']
        sim_mode1, sim_mode2 = sim_data['Cube 1 Mode'], sim_data['Cube 2 Mode']

        # Check if modes correspond
        modes_correspond = (seq_mode1 == sim_mode1) and (seq_mode2 == sim_mode2)
        print(f"Comparing {seq_file} (Sequential) and {sim_file} (Simultaneous): Modes correspond? {modes_correspond}")

    except StopIteration:
        # One of the dictionaries has been fully iterated
        break
# Out:
# Comparing File_0 (Sequential) and File_10 (Simultaneous): Modes correspond? True
# Comparing File_1 (Sequential) and File_11 (Simultaneous): Modes correspond? True
# Comparing File_2 (Sequential) and File_12 (Simultaneous): Modes correspond? True
# Comparing File_3 (Sequential) and File_13 (Simultaneous): Modes correspond? True
# Comparing File_4 (Sequential) and File_14 (Simultaneous): Modes correspond? True
# Comparing File_5 (Sequential) and File_15 (Simultaneous): Modes correspond? True
# Comparing File_6 (Sequential) and File_16 (Simultaneous): Modes correspond? True
# Comparing File_7 (Sequential) and File_17 (Simultaneous): Modes correspond? True
# Comparing File_8 (Sequential) and File_18 (Simultaneous): Modes correspond? True
# Comparing File_9 (Sequential) and File_19 (Simultaneous): Modes correspond? True
# Comparing File_20 (Sequential) and File_30 (Simultaneous): Modes correspond? True
# Comparing File_21 (Sequential) and File_31 (Simultaneous): Modes correspond? True
# Comparing File_22 (Sequential) and File_32 (Simultaneous): Modes correspond? True
# Comparing File_23 (Sequential) and File_33 (Simultaneous): Modes correspond? True
# Comparing File_24 (Sequential) and File_34 (Simultaneous): Modes correspond? True
# Comparing File_25 (Sequential) and File_35 (Simultaneous): Modes correspond? True
# Comparing File_26 (Sequential) and File_36 (Simultaneous): Modes correspond? True
# Comparing File_27 (Sequential) and File_37 (Simultaneous): Modes correspond? True
# Comparing File_28 (Sequential) and File_38 (Simultaneous): Modes correspond? True
# Comparing File_29 (Sequential) and File_39 (Simultaneous): Modes correspond? True
# Comparing File_40 (Sequential) and File_55 (Simultaneous): Modes correspond? True
# Comparing File_41 (Sequential) and File_56 (Simultaneous): Modes correspond? True
# Comparing File_42 (Sequential) and File_57 (Simultaneous): Modes correspond? True
# Comparing File_43 (Sequential) and File_58 (Simultaneous): Modes correspond? True
# Comparing File_44 (Sequential) and File_59 (Simultaneous): Modes correspond? True
# Comparing File_45 (Sequential) and File_60 (Simultaneous): Modes correspond? True
# Comparing File_46 (Sequential) and File_61 (Simultaneous): Modes correspond? True
# Comparing File_47 (Sequential) and File_62 (Simultaneous): Modes correspond? True
# Comparing File_48 (Sequential) and File_63 (Simultaneous): Modes correspond? True
# Comparing File_49 (Sequential) and File_64 (Simultaneous): Modes correspond? True
# Comparing File_50 (Sequential) and File_65 (Simultaneous): Modes correspond? True
# Comparing File_51 (Sequential) and File_66 (Simultaneous): Modes correspond? True
# Comparing File_52 (Sequential) and File_67 (Simultaneous): Modes correspond? True
# Comparing File_53 (Sequential) and File_68 (Simultaneous): Modes correspond? True
# Comparing File_54 (Sequential) and File_69 (Simultaneous): Modes correspond? True
# Comparing File_70 (Sequential) and File_85 (Simultaneous): Modes correspond? True
# Comparing File_71 (Sequential) and File_86 (Simultaneous): Modes correspond? True
# Comparing File_72 (Sequential) and File_87 (Simultaneous): Modes correspond? True
# Comparing File_73 (Sequential) and File_88 (Simultaneous): Modes correspond? True
# Comparing File_74 (Sequential) and File_89 (Simultaneous): Modes correspond? True
# Comparing File_75 (Sequential) and File_90 (Simultaneous): Modes correspond? True
# Comparing File_76 (Sequential) and File_91 (Simultaneous): Modes correspond? True
# Comparing File_77 (Sequential) and File_92 (Simultaneous): Modes correspond? True
# Comparing File_78 (Sequential) and File_93 (Simultaneous): Modes correspond? True
# Comparing File_79 (Sequential) and File_94 (Simultaneous): Modes correspond? True
# Comparing File_80 (Sequential) and File_95 (Simultaneous): Modes correspond? True
# Comparing File_81 (Sequential) and File_96 (Simultaneous): Modes correspond? True
# Comparing File_82 (Sequential) and File_97 (Simultaneous): Modes correspond? True
# Comparing File_83 (Sequential) and File_98 (Simultaneous): Modes correspond? True
# Comparing File_84 (Sequential) and File_99 (Simultaneous): Modes correspond? True
# Comparing File_100 (Sequential) and File_115 (Simultaneous): Modes correspond? True
# Comparing File_101 (Sequential) and File_116 (Simultaneous): Modes correspond? True
# Comparing File_102 (Sequential) and File_117 (Simultaneous): Modes correspond? True
# Comparing File_103 (Sequential) and File_118 (Simultaneous): Modes correspond? True
# Comparing File_104 (Sequential) and File_119 (Simultaneous): Modes correspond? True
# Comparing File_105 (Sequential) and File_120 (Simultaneous): Modes correspond? True
# Comparing File_106 (Sequential) and File_121 (Simultaneous): Modes correspond? True
# Comparing File_107 (Sequential) and File_122 (Simultaneous): Modes correspond? True
# Comparing File_108 (Sequential) and File_123 (Simultaneous): Modes correspond? True
# Comparing File_109 (Sequential) and File_124 (Simultaneous): Modes correspond? True
# Comparing File_110 (Sequential) and File_125 (Simultaneous): Modes correspond? True
# Comparing File_111 (Sequential) and File_126 (Simultaneous): Modes correspond? True
# Comparing File_112 (Sequential) and File_127 (Simultaneous): Modes correspond? True
# Comparing File_113 (Sequential) and File_128 (Simultaneous): Modes correspond? True
# Comparing File_114 (Sequential) and File_129 (Simultaneous): Modes correspond? True
# Comparing File_130 (Sequential) and File_145 (Simultaneous): Modes correspond? True
# Comparing File_131 (Sequential) and File_146 (Simultaneous): Modes correspond? True
# Comparing File_132 (Sequential) and File_147 (Simultaneous): Modes correspond? True
# Comparing File_133 (Sequential) and File_148 (Simultaneous): Modes correspond? True
# Comparing File_134 (Sequential) and File_149 (Simultaneous): Modes correspond? True
# Comparing File_135 (Sequential) and File_150 (Simultaneous): Modes correspond? True
# Comparing File_136 (Sequential) and File_151 (Simultaneous): Modes correspond? True
# Comparing File_137 (Sequential) and File_152 (Simultaneous): Modes correspond? True
# Comparing File_138 (Sequential) and File_153 (Simultaneous): Modes correspond? True
# Comparing File_139 (Sequential) and File_154 (Simultaneous): Modes correspond? True
# Comparing File_140 (Sequential) and File_155 (Simultaneous): Modes correspond? True
# Comparing File_141 (Sequential) and File_156 (Simultaneous): Modes correspond? True
# Comparing File_142 (Sequential) and File_157 (Simultaneous): Modes correspond? True
# Comparing File_143 (Sequential) and File_158 (Simultaneous): Modes correspond? True
# Comparing File_144 (Sequential) and File_159 (Simultaneous): Modes correspond? True
# Comparing File_160 (Sequential) and File_175 (Simultaneous): Modes correspond? True
# Comparing File_161 (Sequential) and File_176 (Simultaneous): Modes correspond? True
# Comparing File_162 (Sequential) and File_177 (Simultaneous): Modes correspond? True
# Comparing File_163 (Sequential) and File_178 (Simultaneous): Modes correspond? True
# Comparing File_164 (Sequential) and File_179 (Simultaneous): Modes correspond? True
# Comparing File_165 (Sequential) and File_180 (Simultaneous): Modes correspond? True
# Comparing File_166 (Sequential) and File_181 (Simultaneous): Modes correspond? True
# Comparing File_167 (Sequential) and File_182 (Simultaneous): Modes correspond? True
# Comparing File_168 (Sequential) and File_183 (Simultaneous): Modes correspond? True
# Comparing File_169 (Sequential) and File_184 (Simultaneous): Modes correspond? True
# Comparing File_170 (Sequential) and File_185 (Simultaneous): Modes correspond? True
# Comparing File_171 (Sequential) and File_186 (Simultaneous): Modes correspond? True
# Comparing File_172 (Sequential) and File_187 (Simultaneous): Modes correspond? True
# Comparing File_173 (Sequential) and File_188 (Simultaneous): Modes correspond? True
# Comparing File_174 (Sequential) and File_189 (Simultaneous): Modes correspond? True
# Comparing File_190 (Sequential) and File_205 (Simultaneous): Modes correspond? True
# Comparing File_191 (Sequential) and File_206 (Simultaneous): Modes correspond? True
# Comparing File_192 (Sequential) and File_207 (Simultaneous): Modes correspond? True
# Comparing File_193 (Sequential) and File_208 (Simultaneous): Modes correspond? True
# Comparing File_194 (Sequential) and File_209 (Simultaneous): Modes correspond? True
# Comparing File_195 (Sequential) and File_210 (Simultaneous): Modes correspond? True
# Comparing File_196 (Sequential) and File_211 (Simultaneous): Modes correspond? True
# Comparing File_197 (Sequential) and File_212 (Simultaneous): Modes correspond? True
# Comparing File_198 (Sequential) and File_213 (Simultaneous): Modes correspond? True
# Comparing File_199 (Sequential) and File_214 (Simultaneous): Modes correspond? True
# Comparing File_200 (Sequential) and File_215 (Simultaneous): Modes correspond? True
# Comparing File_201 (Sequential) and File_216 (Simultaneous): Modes correspond? True
# Comparing File_202 (Sequential) and File_217 (Simultaneous): Modes correspond? True
# Comparing File_203 (Sequential) and File_218 (Simultaneous): Modes correspond? True
# Comparing File_204 (Sequential) and File_219 (Simultaneous): Modes correspond? True
# Comparing File_220 (Sequential) and File_235 (Simultaneous): Modes correspond? True
# Comparing File_221 (Sequential) and File_236 (Simultaneous): Modes correspond? True
# Comparing File_222 (Sequential) and File_237 (Simultaneous): Modes correspond? True
# Comparing File_223 (Sequential) and File_238 (Simultaneous): Modes correspond? True
# Comparing File_224 (Sequential) and File_239 (Simultaneous): Modes correspond? True
# Comparing File_225 (Sequential) and File_240 (Simultaneous): Modes correspond? True
# Comparing File_226 (Sequential) and File_241 (Simultaneous): Modes correspond? True
# Comparing File_227 (Sequential) and File_242 (Simultaneous): Modes correspond? True
# Comparing File_228 (Sequential) and File_243 (Simultaneous): Modes correspond? True
# Comparing File_229 (Sequential) and File_244 (Simultaneous): Modes correspond? True
# Comparing File_230 (Sequential) and File_245 (Simultaneous): Modes correspond? True
# Comparing File_231 (Sequential) and File_246 (Simultaneous): Modes correspond? True
# Comparing File_232 (Sequential) and File_247 (Simultaneous): Modes correspond? True
# Comparing File_233 (Sequential) and File_248 (Simultaneous): Modes correspond? True
# Comparing File_234 (Sequential) and File_249 (Simultaneous): Modes correspond? True
# Comparing File_250 (Sequential) and File_265 (Simultaneous): Modes correspond? True
# Comparing File_251 (Sequential) and File_266 (Simultaneous): Modes correspond? True
# Comparing File_252 (Sequential) and File_267 (Simultaneous): Modes correspond? True
# Comparing File_253 (Sequential) and File_268 (Simultaneous): Modes correspond? True
# Comparing File_254 (Sequential) and File_269 (Simultaneous): Modes correspond? True
# Comparing File_255 (Sequential) and File_270 (Simultaneous): Modes correspond? True
# Comparing File_256 (Sequential) and File_271 (Simultaneous): Modes correspond? True
# Comparing File_257 (Sequential) and File_272 (Simultaneous): Modes correspond? True
# Comparing File_258 (Sequential) and File_273 (Simultaneous): Modes correspond? True
# Comparing File_259 (Sequential) and File_274 (Simultaneous): Modes correspond? True
# Comparing File_260 (Sequential) and File_275 (Simultaneous): Modes correspond? True
# Comparing File_261 (Sequential) and File_276 (Simultaneous): Modes correspond? True
# Comparing File_262 (Sequential) and File_277 (Simultaneous): Modes correspond? True
# Comparing File_263 (Sequential) and File_278 (Simultaneous): Modes correspond? True
# Comparing File_264 (Sequential) and File_279 (Simultaneous): Modes correspond? True
# Comparing File_280 (Sequential) and File_295 (Simultaneous): Modes correspond? True
# Comparing File_281 (Sequential) and File_296 (Simultaneous): Modes correspond? True
# Comparing File_282 (Sequential) and File_297 (Simultaneous): Modes correspond? True
# Comparing File_283 (Sequential) and File_298 (Simultaneous): Modes correspond? True
# Comparing File_284 (Sequential) and File_299 (Simultaneous): Modes correspond? True
# Comparing File_285 (Sequential) and File_300 (Simultaneous): Modes correspond? True
# Comparing File_286 (Sequential) and File_301 (Simultaneous): Modes correspond? True
# Comparing File_287 (Sequential) and File_302 (Simultaneous): Modes correspond? True
# Comparing File_288 (Sequential) and File_303 (Simultaneous): Modes correspond? True
# Comparing File_289 (Sequential) and File_304 (Simultaneous): Modes correspond? True
# Comparing File_290 (Sequential) and File_305 (Simultaneous): Modes correspond? True
# Comparing File_291 (Sequential) and File_306 (Simultaneous): Modes correspond? True
# Comparing File_292 (Sequential) and File_307 (Simultaneous): Modes correspond? True
# Comparing File_293 (Sequential) and File_308 (Simultaneous): Modes correspond? True
# Comparing File_294 (Sequential) and File_309 (Simultaneous): Modes correspond? True
# Comparing File_310 (Sequential) and File_325 (Simultaneous): Modes correspond? True
# Comparing File_311 (Sequential) and File_326 (Simultaneous): Modes correspond? True
# Comparing File_312 (Sequential) and File_327 (Simultaneous): Modes correspond? True
# Comparing File_313 (Sequential) and File_328 (Simultaneous): Modes correspond? True
# Comparing File_314 (Sequential) and File_329 (Simultaneous): Modes correspond? True
# Comparing File_315 (Sequential) and File_330 (Simultaneous): Modes correspond? True
# Comparing File_316 (Sequential) and File_331 (Simultaneous): Modes correspond? True
# Comparing File_317 (Sequential) and File_332 (Simultaneous): Modes correspond? True
# Comparing File_318 (Sequential) and File_333 (Simultaneous): Modes correspond? True
# Comparing File_319 (Sequential) and File_334 (Simultaneous): Modes correspond? True
# Comparing File_320 (Sequential) and File_335 (Simultaneous): Modes correspond? True
# Comparing File_321 (Sequential) and File_336 (Simultaneous): Modes correspond? True
# Comparing File_322 (Sequential) and File_337 (Simultaneous): Modes correspond? True
# Comparing File_323 (Sequential) and File_338 (Simultaneous): Modes correspond? True
# Comparing File_324 (Sequential) and File_339 (Simultaneous): Modes correspond? True
# Comparing File_340 (Sequential) and File_355 (Simultaneous): Modes correspond? True
# Comparing File_341 (Sequential) and File_356 (Simultaneous): Modes correspond? True
# Comparing File_342 (Sequential) and File_357 (Simultaneous): Modes correspond? True
# Comparing File_343 (Sequential) and File_358 (Simultaneous): Modes correspond? True
# Comparing File_344 (Sequential) and File_359 (Simultaneous): Modes correspond? True
# Comparing File_345 (Sequential) and File_360 (Simultaneous): Modes correspond? True
# Comparing File_346 (Sequential) and File_361 (Simultaneous): Modes correspond? True
# Comparing File_347 (Sequential) and File_362 (Simultaneous): Modes correspond? True
# Comparing File_348 (Sequential) and File_363 (Simultaneous): Modes correspond? True
# Comparing File_349 (Sequential) and File_364 (Simultaneous): Modes correspond? True
# Comparing File_350 (Sequential) and File_365 (Simultaneous): Modes correspond? True
# Comparing File_351 (Sequential) and File_366 (Simultaneous): Modes correspond? True
# Comparing File_352 (Sequential) and File_367 (Simultaneous): Modes correspond? True
# Comparing File_353 (Sequential) and File_368 (Simultaneous): Modes correspond? True
# Comparing File_354 (Sequential) and File_369 (Simultaneous): Modes correspond? True
# Comparing File_370 (Sequential) and File_385 (Simultaneous): Modes correspond? True
# Comparing File_371 (Sequential) and File_386 (Simultaneous): Modes correspond? True
# Comparing File_372 (Sequential) and File_387 (Simultaneous): Modes correspond? True
# Comparing File_373 (Sequential) and File_388 (Simultaneous): Modes correspond? True
# Comparing File_374 (Sequential) and File_389 (Simultaneous): Modes correspond? True
# Comparing File_375 (Sequential) and File_390 (Simultaneous): Modes correspond? True
# Comparing File_376 (Sequential) and File_391 (Simultaneous): Modes correspond? True
# Comparing File_377 (Sequential) and File_392 (Simultaneous): Modes correspond? True
# Comparing File_378 (Sequential) and File_393 (Simultaneous): Modes correspond? True
# Comparing File_379 (Sequential) and File_394 (Simultaneous): Modes correspond? True
# Comparing File_380 (Sequential) and File_395 (Simultaneous): Modes correspond? True
# Comparing File_381 (Sequential) and File_396 (Simultaneous): Modes correspond? True
# Comparing File_382 (Sequential) and File_397 (Simultaneous): Modes correspond? True
# Comparing File_383 (Sequential) and File_398 (Simultaneous): Modes correspond? True
# Comparing File_384 (Sequential) and File_399 (Simultaneous): Modes correspond? True

# %%
sequential_dict['File_0']
# Out:
# {'Cube 1 Mode': 'Conduction 2',
#  'Cube 2 Mode': 'Conduction 2',
#  'channels': {'Channel_1': {'segment': [array([ 1.631012 ,  1.408844 ,  1.222229 , ..., -0.266571 ,  0.9873962,
#             1.666107 ]),
#     array([1.638641 , 1.416626 , 1.22818  , ..., 0.7533264, 1.670532 ,
#            1.550293 ])]},
#   'Channel_2': {'segment': [array([1.632233 , 1.443176 , 1.282196 , ..., 0.1829529, 0.5187988,
#            1.531677 ]),
#     array([1.618042, 1.433105, 1.274261, ..., 0.852356, 1.535187, 1.585083])]},
#   'Channel_3': {'segment': [array([ 0.00335693,  0.00610352, -0.00152588, ..., -0.00305176,
#            -0.00762939, -0.00671387]),
#     array([-0.05386353, -0.04058838, -0.00991821, ...,  0.00106811,
#            -0.00350952, -0.00076294])]}}}

# %%
# Initialize variables to track the minimum segment lengths
min_lengths = []

# Process each dictionary separately due to their differing structures and needs
for operation_dict, operation_type in zip([sequential_dict, simultaneous_dict], ['Sequential', 'Simultaneous']):
    print(f"Processing {operation_type} data")

    for file_name, file_data in operation_dict.items():
        print(f"Processing file: {file_name}...")

        # Initialize lists to store segments and their descriptions
        segments = []
        descriptions = []

        # Differing processing logic based on operation type
        if operation_type == 'Sequential':
            for channel_name, channel_data in file_data['channels'].items():
                for idx, seg in enumerate(channel_data['segment']):
                    segments.append(seg)
                    mode = file_data['Cube 1 Mode'] if idx == 0 else file_data['Cube 2 Mode']
                    descriptions.append(f"Channel: {channel_name}, Mode: {mode}")
        
        elif operation_type == 'Simultaneous':
            for channel_name, channel_data in file_data['channels'].items():
                segments.extend(channel_data['segment'])
                description = f"Channel: {channel_name}, Modes: {file_data['Cube 1 Mode']} & {file_data['Cube 2 Mode']}"
                descriptions.extend([description] * len(channel_data['segment']))
        
        # After processing each file, find the minimum segment length for the file
        if segments:  # Ensure there are segments processed before attempting to find the minimum
            min_length = min(len(seg) for seg in segments)
            min_lengths.append(min_length)
            print(f"Minimum segment length for {file_name} in {operation_type} operation: {min_length}")

# Find the global minimum segment length across all files and operation types
if min_lengths:  # Ensure there are minimum lengths calculated before attempting to find the global minimum
    global_min_length = min(min_lengths)
    print(f"Global minimum segment length across all operations: {global_min_length}")
else:
    print("No segment lengths were found to calculate a global minimum.")
# Out:
# Processing Sequential data
# Processing file: File_0...
# Minimum segment length for File_0 in Sequential operation: 426195
# Processing file: File_1...
# Minimum segment length for File_1 in Sequential operation: 426211
# Processing file: File_2...
# Minimum segment length for File_2 in Sequential operation: 427173
# Processing file: File_3...
# Minimum segment length for File_3 in Sequential operation: 425757
# Processing file: File_4...
# Minimum segment length for File_4 in Sequential operation: 427121
# Processing file: File_5...
# Minimum segment length for File_5 in Sequential operation: 425909
# Processing file: File_6...
# Minimum segment length for File_6 in Sequential operation: 426857
# Processing file: File_7...
# Minimum segment length for File_7 in Sequential operation: 425269
# Processing file: File_8...
# Minimum segment length for File_8 in Sequential operation: 425631
# Processing file: File_9...
# Minimum segment length for File_9 in Sequential operation: 424639
# Processing file: File_20...
# Minimum segment length for File_20 in Sequential operation: 426117
# Processing file: File_21...
# Minimum segment length for File_21 in Sequential operation: 425017
# Processing file: File_22...
# Minimum segment length for File_22 in Sequential operation: 426241
# Processing file: File_23...
# Minimum segment length for File_23 in Sequential operation: 424048
# Processing file: File_24...
# Minimum segment length for File_24 in Sequential operation: 425552
# Processing file: File_25...
# Minimum segment length for File_25 in Sequential operation: 424107
# Processing file: File_26...
# Minimum segment length for File_26 in Sequential operation: 424844
# Processing file: File_27...
# Minimum segment length for File_27 in Sequential operation: 424694
# Processing file: File_28...
# Minimum segment length for File_28 in Sequential operation: 424682
# Processing file: File_29...
# Minimum segment length for File_29 in Sequential operation: 424222
# Processing file: File_40...
# Minimum segment length for File_40 in Sequential operation: 482435
# Processing file: File_41...
# Minimum segment length for File_41 in Sequential operation: 482415
# Processing file: File_42...
# Minimum segment length for File_42 in Sequential operation: 483747
# Processing file: File_43...
# Minimum segment length for File_43 in Sequential operation: 481635
# Processing file: File_44...
# Minimum segment length for File_44 in Sequential operation: 483632
# Processing file: File_45...
# Minimum segment length for File_45 in Sequential operation: 481309
# Processing file: File_46...
# Minimum segment length for File_46 in Sequential operation: 483211
# Processing file: File_47...
# Minimum segment length for File_47 in Sequential operation: 482222
# Processing file: File_48...
# Minimum segment length for File_48 in Sequential operation: 482962
# Processing file: File_49...
# Minimum segment length for File_49 in Sequential operation: 483125
# Processing file: File_50...
# Minimum segment length for File_50 in Sequential operation: 482854
# Processing file: File_51...
# Minimum segment length for File_51 in Sequential operation: 482166
# Processing file: File_52...
# Minimum segment length for File_52 in Sequential operation: 483351
# Processing file: File_53...
# Minimum segment length for File_53 in Sequential operation: 482327
# Processing file: File_54...
# Minimum segment length for File_54 in Sequential operation: 482543
# Processing file: File_70...
# Minimum segment length for File_70 in Sequential operation: 424983
# Processing file: File_71...
# Minimum segment length for File_71 in Sequential operation: 423838
# Processing file: File_72...
# Minimum segment length for File_72 in Sequential operation: 425788
# Processing file: File_73...
# Minimum segment length for File_73 in Sequential operation: 424201
# Processing file: File_74...
# Minimum segment length for File_74 in Sequential operation: 425054
# Processing file: File_75...
# Minimum segment length for File_75 in Sequential operation: 424497
# Processing file: File_76...
# Minimum segment length for File_76 in Sequential operation: 425116
# Processing file: File_77...
# Minimum segment length for File_77 in Sequential operation: 424677
# Processing file: File_78...
# Minimum segment length for File_78 in Sequential operation: 424799
# Processing file: File_79...
# Minimum segment length for File_79 in Sequential operation: 424237
# Processing file: File_80...
# Minimum segment length for File_80 in Sequential operation: 425341
# Processing file: File_81...
# Minimum segment length for File_81 in Sequential operation: 423848
# Processing file: File_82...
# Minimum segment length for File_82 in Sequential operation: 425121
# Processing file: File_83...
# Minimum segment length for File_83 in Sequential operation: 424414
# Processing file: File_84...
# Minimum segment length for File_84 in Sequential operation: 424907
# Processing file: File_100...
# Minimum segment length for File_100 in Sequential operation: 380679
# Processing file: File_101...
# Minimum segment length for File_101 in Sequential operation: 379844
# Processing file: File_102...
# Minimum segment length for File_102 in Sequential operation: 380739
# Processing file: File_103...
# Minimum segment length for File_103 in Sequential operation: 379368
# Processing file: File_104...
# Minimum segment length for File_104 in Sequential operation: 381072
# Processing file: File_105...
# Minimum segment length for File_105 in Sequential operation: 379645
# Processing file: File_106...
# Minimum segment length for File_106 in Sequential operation: 380380
# Processing file: File_107...
# Minimum segment length for File_107 in Sequential operation: 379696
# Processing file: File_108...
# Minimum segment length for File_108 in Sequential operation: 379699
# Processing file: File_109...
# Minimum segment length for File_109 in Sequential operation: 378986
# Processing file: File_110...
# Minimum segment length for File_110 in Sequential operation: 380447
# Processing file: File_111...
# Minimum segment length for File_111 in Sequential operation: 379665
# Processing file: File_112...
# Minimum segment length for File_112 in Sequential operation: 380264
# Processing file: File_113...
# Minimum segment length for File_113 in Sequential operation: 379458
# Processing file: File_114...
# Minimum segment length for File_114 in Sequential operation: 380852
# Processing file: File_130...
# Minimum segment length for File_130 in Sequential operation: 482824
# Processing file: File_131...
# Minimum segment length for File_131 in Sequential operation: 483561
# Processing file: File_132...
# Minimum segment length for File_132 in Sequential operation: 481506
# Processing file: File_133...
# Minimum segment length for File_133 in Sequential operation: 483308
# Processing file: File_134...
# Minimum segment length for File_134 in Sequential operation: 482739
# Processing file: File_135...
# Minimum segment length for File_135 in Sequential operation: 482424
# Processing file: File_136...
# Minimum segment length for File_136 in Sequential operation: 482822
# Processing file: File_137...
# Minimum segment length for File_137 in Sequential operation: 483408
# Processing file: File_138...
# Minimum segment length for File_138 in Sequential operation: 483238
# Processing file: File_139...
# Minimum segment length for File_139 in Sequential operation: 483653
# Processing file: File_140...
# Minimum segment length for File_140 in Sequential operation: 482889
# Processing file: File_141...
# Minimum segment length for File_141 in Sequential operation: 483723
# Processing file: File_142...
# Minimum segment length for File_142 in Sequential operation: 483227
# Processing file: File_143...
# Minimum segment length for File_143 in Sequential operation: 483284
# Processing file: File_144...
# Minimum segment length for File_144 in Sequential operation: 482274
# Processing file: File_160...
# Minimum segment length for File_160 in Sequential operation: 483311
# Processing file: File_161...
# Minimum segment length for File_161 in Sequential operation: 481530
# Processing file: File_162...
# Minimum segment length for File_162 in Sequential operation: 484971
# Processing file: File_163...
# Minimum segment length for File_163 in Sequential operation: 482462
# Processing file: File_164...
# Minimum segment length for File_164 in Sequential operation: 483663
# Processing file: File_165...
# Minimum segment length for File_165 in Sequential operation: 481945
# Processing file: File_166...
# Minimum segment length for File_166 in Sequential operation: 484385
# Processing file: File_167...
# Minimum segment length for File_167 in Sequential operation: 482043
# Processing file: File_168...
# Minimum segment length for File_168 in Sequential operation: 484354
# Processing file: File_169...
# Minimum segment length for File_169 in Sequential operation: 482132
# Processing file: File_170...
# Minimum segment length for File_170 in Sequential operation: 483917
# Processing file: File_171...
# Minimum segment length for File_171 in Sequential operation: 482156
# Processing file: File_172...
# Minimum segment length for File_172 in Sequential operation: 484063
# Processing file: File_173...
# Minimum segment length for File_173 in Sequential operation: 481977
# Processing file: File_174...
# Minimum segment length for File_174 in Sequential operation: 484762
# Processing file: File_190...
# Minimum segment length for File_190 in Sequential operation: 424762
# Processing file: File_191...
# Minimum segment length for File_191 in Sequential operation: 424645
# Processing file: File_192...
# Minimum segment length for File_192 in Sequential operation: 425638
# Processing file: File_193...
# Minimum segment length for File_193 in Sequential operation: 425971
# Processing file: File_194...
# Minimum segment length for File_194 in Sequential operation: 425224
# Processing file: File_195...
# Minimum segment length for File_195 in Sequential operation: 424862
# Processing file: File_196...
# Minimum segment length for File_196 in Sequential operation: 425167
# Processing file: File_197...
# Minimum segment length for File_197 in Sequential operation: 424808
# Processing file: File_198...
# Minimum segment length for File_198 in Sequential operation: 425141
# Processing file: File_199...
# Minimum segment length for File_199 in Sequential operation: 425404
# Processing file: File_200...
# Minimum segment length for File_200 in Sequential operation: 425054
# Processing file: File_201...
# Minimum segment length for File_201 in Sequential operation: 424955
# Processing file: File_202...
# Minimum segment length for File_202 in Sequential operation: 425468
# Processing file: File_203...
# Minimum segment length for File_203 in Sequential operation: 425378
# Processing file: File_204...
# Minimum segment length for File_204 in Sequential operation: 425373
# Processing file: File_220...
# Minimum segment length for File_220 in Sequential operation: 424744
# Processing file: File_221...
# Minimum segment length for File_221 in Sequential operation: 424200
# Processing file: File_222...
# Minimum segment length for File_222 in Sequential operation: 425609
# Processing file: File_223...
# Minimum segment length for File_223 in Sequential operation: 424169
# Processing file: File_224...
# Minimum segment length for File_224 in Sequential operation: 426081
# Processing file: File_225...
# Minimum segment length for File_225 in Sequential operation: 424092
# Processing file: File_226...
# Minimum segment length for File_226 in Sequential operation: 426182
# Processing file: File_227...
# Minimum segment length for File_227 in Sequential operation: 424530
# Processing file: File_228...
# Minimum segment length for File_228 in Sequential operation: 425826
# Processing file: File_229...
# Minimum segment length for File_229 in Sequential operation: 423480
# Processing file: File_230...
# Minimum segment length for File_230 in Sequential operation: 426604
# Processing file: File_231...
# Minimum segment length for File_231 in Sequential operation: 425051
# Processing file: File_232...
# Minimum segment length for File_232 in Sequential operation: 427178
# Processing file: File_233...
# Minimum segment length for File_233 in Sequential operation: 424053
# Processing file: File_234...
# Minimum segment length for File_234 in Sequential operation: 426023
# Processing file: File_250...
# Minimum segment length for File_250 in Sequential operation: 380501
# Processing file: File_251...
# Minimum segment length for File_251 in Sequential operation: 379779
# Processing file: File_252...
# Minimum segment length for File_252 in Sequential operation: 380311
# Processing file: File_253...
# Minimum segment length for File_253 in Sequential operation: 380626
# Processing file: File_254...
# Minimum segment length for File_254 in Sequential operation: 380815
# Processing file: File_255...
# Minimum segment length for File_255 in Sequential operation: 380574
# Processing file: File_256...
# Minimum segment length for File_256 in Sequential operation: 380409
# Processing file: File_257...
# Minimum segment length for File_257 in Sequential operation: 379925
# Processing file: File_258...
# Minimum segment length for File_258 in Sequential operation: 380439
# Processing file: File_259...
# Minimum segment length for File_259 in Sequential operation: 379920
# Processing file: File_260...
# Minimum segment length for File_260 in Sequential operation: 380703
# Processing file: File_261...
# Minimum segment length for File_261 in Sequential operation: 380443
# Processing file: File_262...
# Minimum segment length for File_262 in Sequential operation: 380400
# Processing file: File_263...
# Minimum segment length for File_263 in Sequential operation: 380491
# Processing file: File_264...
# Minimum segment length for File_264 in Sequential operation: 380767
# Processing file: File_280...
# Minimum segment length for File_280 in Sequential operation: 380627
# Processing file: File_281...
# Minimum segment length for File_281 in Sequential operation: 379262
# Processing file: File_282...
# Minimum segment length for File_282 in Sequential operation: 380904
# Processing file: File_283...
# Minimum segment length for File_283 in Sequential operation: 379482
# Processing file: File_284...
# Minimum segment length for File_284 in Sequential operation: 381351
# Processing file: File_285...
# Minimum segment length for File_285 in Sequential operation: 379365
# Processing file: File_286...
# Minimum segment length for File_286 in Sequential operation: 381474
# Processing file: File_287...
# Minimum segment length for File_287 in Sequential operation: 380103
# Processing file: File_288...
# Minimum segment length for File_288 in Sequential operation: 381831
# Processing file: File_289...
# Minimum segment length for File_289 in Sequential operation: 380136
# Processing file: File_290...
# Minimum segment length for File_290 in Sequential operation: 381808
# Processing file: File_291...
# Minimum segment length for File_291 in Sequential operation: 379987
# Processing file: File_292...
# Minimum segment length for File_292 in Sequential operation: 381905
# Processing file: File_293...
# Minimum segment length for File_293 in Sequential operation: 379913
# Processing file: File_294...
# Minimum segment length for File_294 in Sequential operation: 380934
# Processing file: File_310...
# Minimum segment length for File_310 in Sequential operation: 669037
# Processing file: File_311...
# Minimum segment length for File_311 in Sequential operation: 669384
# Processing file: File_312...
# Minimum segment length for File_312 in Sequential operation: 669437
# Processing file: File_313...
# Minimum segment length for File_313 in Sequential operation: 669042
# Processing file: File_314...
# Minimum segment length for File_314 in Sequential operation: 668915
# Processing file: File_315...
# Minimum segment length for File_315 in Sequential operation: 668682
# Processing file: File_316...
# Minimum segment length for File_316 in Sequential operation: 668921
# Processing file: File_317...
# Minimum segment length for File_317 in Sequential operation: 668234
# Processing file: File_318...
# Minimum segment length for File_318 in Sequential operation: 668298
# Processing file: File_319...
# Minimum segment length for File_319 in Sequential operation: 668450
# Processing file: File_320...
# Minimum segment length for File_320 in Sequential operation: 669330
# Processing file: File_321...
# Minimum segment length for File_321 in Sequential operation: 667918
# Processing file: File_322...
# Minimum segment length for File_322 in Sequential operation: 669152
# Processing file: File_323...
# Minimum segment length for File_323 in Sequential operation: 668424
# Processing file: File_324...
# Minimum segment length for File_324 in Sequential operation: 668462
# Processing file: File_340...
# Minimum segment length for File_340 in Sequential operation: 669286
# Processing file: File_341...
# Minimum segment length for File_341 in Sequential operation: 669098
# Processing file: File_342...
# Minimum segment length for File_342 in Sequential operation: 668935
# Processing file: File_343...
# Minimum segment length for File_343 in Sequential operation: 668781
# Processing file: File_344...
# Minimum segment length for File_344 in Sequential operation: 668930
# Processing file: File_345...
# Minimum segment length for File_345 in Sequential operation: 669132
# Processing file: File_346...
# Minimum segment length for File_346 in Sequential operation: 669085
# Processing file: File_347...
# Minimum segment length for File_347 in Sequential operation: 668565
# Processing file: File_348...
# Minimum segment length for File_348 in Sequential operation: 669762
# Processing file: File_349...
# Minimum segment length for File_349 in Sequential operation: 668539
# Processing file: File_350...
# Minimum segment length for File_350 in Sequential operation: 668529
# Processing file: File_351...
# Minimum segment length for File_351 in Sequential operation: 669029
# Processing file: File_352...
# Minimum segment length for File_352 in Sequential operation: 669808
# Processing file: File_353...
# Minimum segment length for File_353 in Sequential operation: 669253
# Processing file: File_354...
# Minimum segment length for File_354 in Sequential operation: 668516
# Processing file: File_370...
# Minimum segment length for File_370 in Sequential operation: 668337
# Processing file: File_371...
# Minimum segment length for File_371 in Sequential operation: 669058
# Processing file: File_372...
# Minimum segment length for File_372 in Sequential operation: 669119
# Processing file: File_373...
# Minimum segment length for File_373 in Sequential operation: 669094
# Processing file: File_374...
# Minimum segment length for File_374 in Sequential operation: 668919
# Processing file: File_375...
# Minimum segment length for File_375 in Sequential operation: 668252
# Processing file: File_376...
# Minimum segment length for File_376 in Sequential operation: 669247
# Processing file: File_377...
# Minimum segment length for File_377 in Sequential operation: 669110
# Processing file: File_378...
# Minimum segment length for File_378 in Sequential operation: 668863
# Processing file: File_379...
# Minimum segment length for File_379 in Sequential operation: 669252
# Processing file: File_380...
# Minimum segment length for File_380 in Sequential operation: 668829
# Processing file: File_381...
# Minimum segment length for File_381 in Sequential operation: 669061
# Processing file: File_382...
# Minimum segment length for File_382 in Sequential operation: 669229
# Processing file: File_383...
# Minimum segment length for File_383 in Sequential operation: 669198
# Processing file: File_384...
# Minimum segment length for File_384 in Sequential operation: 669215
# Processing Simultaneous data
# Processing file: File_10...
# Minimum segment length for File_10 in Simultaneous operation: 427633
# Processing file: File_11...
# Minimum segment length for File_11 in Simultaneous operation: 428210
# Processing file: File_12...
# Minimum segment length for File_12 in Simultaneous operation: 429531
# Processing file: File_13...
# Minimum segment length for File_13 in Simultaneous operation: 427829
# Processing file: File_14...
# Minimum segment length for File_14 in Simultaneous operation: 429512
# Processing file: File_15...
# Minimum segment length for File_15 in Simultaneous operation: 427330
# Processing file: File_16...
# Minimum segment length for File_16 in Simultaneous operation: 429260
# Processing file: File_17...
# Minimum segment length for File_17 in Simultaneous operation: 426873
# Processing file: File_18...
# Minimum segment length for File_18 in Simultaneous operation: 429472
# Processing file: File_19...
# Minimum segment length for File_19 in Simultaneous operation: 427351
# Processing file: File_30...
# Minimum segment length for File_30 in Simultaneous operation: 428041
# Processing file: File_31...
# Minimum segment length for File_31 in Simultaneous operation: 427534
# Processing file: File_32...
# Minimum segment length for File_32 in Simultaneous operation: 428064
# Processing file: File_33...
# Minimum segment length for File_33 in Simultaneous operation: 427664
# Processing file: File_34...
# Minimum segment length for File_34 in Simultaneous operation: 428792
# Processing file: File_35...
# Minimum segment length for File_35 in Simultaneous operation: 427251
# Processing file: File_36...
# Minimum segment length for File_36 in Simultaneous operation: 428077
# Processing file: File_37...
# Minimum segment length for File_37 in Simultaneous operation: 428571
# Processing file: File_38...
# Minimum segment length for File_38 in Simultaneous operation: 428797
# Processing file: File_39...
# Minimum segment length for File_39 in Simultaneous operation: 427284
# Processing file: File_55...
# Minimum segment length for File_55 in Simultaneous operation: 485130
# Processing file: File_56...
# Minimum segment length for File_56 in Simultaneous operation: 487552
# Processing file: File_57...
# Minimum segment length for File_57 in Simultaneous operation: 484840
# Processing file: File_58...
# Minimum segment length for File_58 in Simultaneous operation: 487059
# Processing file: File_59...
# Minimum segment length for File_59 in Simultaneous operation: 485408
# Processing file: File_60...
# Minimum segment length for File_60 in Simultaneous operation: 485942
# Processing file: File_61...
# Minimum segment length for File_61 in Simultaneous operation: 485269
# Processing file: File_62...
# Minimum segment length for File_62 in Simultaneous operation: 486129
# Processing file: File_63...
# Minimum segment length for File_63 in Simultaneous operation: 485117
# Processing file: File_64...
# Minimum segment length for File_64 in Simultaneous operation: 486211
# Processing file: File_65...
# Minimum segment length for File_65 in Simultaneous operation: 484741
# Processing file: File_66...
# Minimum segment length for File_66 in Simultaneous operation: 486957
# Processing file: File_67...
# Minimum segment length for File_67 in Simultaneous operation: 485089
# Processing file: File_68...
# Minimum segment length for File_68 in Simultaneous operation: 486367
# Processing file: File_69...
# Minimum segment length for File_69 in Simultaneous operation: 484792
# Processing file: File_85...
# Minimum segment length for File_85 in Simultaneous operation: 427498
# Processing file: File_86...
# Minimum segment length for File_86 in Simultaneous operation: 428148
# Processing file: File_87...
# Minimum segment length for File_87 in Simultaneous operation: 427525
# Processing file: File_88...
# Minimum segment length for File_88 in Simultaneous operation: 429350
# Processing file: File_89...
# Minimum segment length for File_89 in Simultaneous operation: 427190
# Processing file: File_90...
# Minimum segment length for File_90 in Simultaneous operation: 428783
# Processing file: File_91...
# Minimum segment length for File_91 in Simultaneous operation: 426625
# Processing file: File_92...
# Minimum segment length for File_92 in Simultaneous operation: 429247
# Processing file: File_93...
# Minimum segment length for File_93 in Simultaneous operation: 426855
# Processing file: File_94...
# Minimum segment length for File_94 in Simultaneous operation: 429523
# Processing file: File_95...
# Minimum segment length for File_95 in Simultaneous operation: 428057
# Processing file: File_96...
# Minimum segment length for File_96 in Simultaneous operation: 427835
# Processing file: File_97...
# Minimum segment length for File_97 in Simultaneous operation: 427182
# Processing file: File_98...
# Minimum segment length for File_98 in Simultaneous operation: 429004
# Processing file: File_99...
# Minimum segment length for File_99 in Simultaneous operation: 428214
# Processing file: File_115...
# Minimum segment length for File_115 in Simultaneous operation: 382854
# Processing file: File_116...
# Minimum segment length for File_116 in Simultaneous operation: 383816
# Processing file: File_117...
# Minimum segment length for File_117 in Simultaneous operation: 382476
# Processing file: File_118...
# Minimum segment length for File_118 in Simultaneous operation: 383535
# Processing file: File_119...
# Minimum segment length for File_119 in Simultaneous operation: 381643
# Processing file: File_120...
# Minimum segment length for File_120 in Simultaneous operation: 383837
# Processing file: File_121...
# Minimum segment length for File_121 in Simultaneous operation: 382673
# Processing file: File_122...
# Minimum segment length for File_122 in Simultaneous operation: 383868
# Processing file: File_123...
# Minimum segment length for File_123 in Simultaneous operation: 383589
# Processing file: File_124...
# Minimum segment length for File_124 in Simultaneous operation: 384465
# Processing file: File_125...
# Minimum segment length for File_125 in Simultaneous operation: 382784
# Processing file: File_126...
# Minimum segment length for File_126 in Simultaneous operation: 384340
# Processing file: File_127...
# Minimum segment length for File_127 in Simultaneous operation: 382506
# Processing file: File_128...
# Minimum segment length for File_128 in Simultaneous operation: 383728
# Processing file: File_129...
# Minimum segment length for File_129 in Simultaneous operation: 383302
# Processing file: File_145...
# Minimum segment length for File_145 in Simultaneous operation: 670288
# Processing file: File_146...
# Minimum segment length for File_146 in Simultaneous operation: 671550
# Processing file: File_147...
# Minimum segment length for File_147 in Simultaneous operation: 670561
# Processing file: File_148...
# Minimum segment length for File_148 in Simultaneous operation: 670780
# Processing file: File_149...
# Minimum segment length for File_149 in Simultaneous operation: 670759
# Processing file: File_150...
# Minimum segment length for File_150 in Simultaneous operation: 671064
# Processing file: File_151...
# Minimum segment length for File_151 in Simultaneous operation: 671546
# Processing file: File_152...
# Minimum segment length for File_152 in Simultaneous operation: 671261
# Processing file: File_153...
# Minimum segment length for File_153 in Simultaneous operation: 671902
# Processing file: File_154...
# Minimum segment length for File_154 in Simultaneous operation: 671491
# Processing file: File_155...
# Minimum segment length for File_155 in Simultaneous operation: 672283
# Processing file: File_156...
# Minimum segment length for File_156 in Simultaneous operation: 671159
# Processing file: File_157...
# Minimum segment length for File_157 in Simultaneous operation: 671852
# Processing file: File_158...
# Minimum segment length for File_158 in Simultaneous operation: 671692
# Processing file: File_159...
# Minimum segment length for File_159 in Simultaneous operation: 670804
# Processing file: File_175...
# Minimum segment length for File_175 in Simultaneous operation: 671094
# Processing file: File_176...
# Minimum segment length for File_176 in Simultaneous operation: 670381
# Processing file: File_177...
# Minimum segment length for File_177 in Simultaneous operation: 670460
# Processing file: File_178...
# Minimum segment length for File_178 in Simultaneous operation: 669142
# Processing file: File_179...
# Minimum segment length for File_179 in Simultaneous operation: 669662
# Processing file: File_180...
# Minimum segment length for File_180 in Simultaneous operation: 669783
# Processing file: File_181...
# Minimum segment length for File_181 in Simultaneous operation: 670993
# Processing file: File_182...
# Minimum segment length for File_182 in Simultaneous operation: 670206
# Processing file: File_183...
# Minimum segment length for File_183 in Simultaneous operation: 670535
# Processing file: File_184...
# Minimum segment length for File_184 in Simultaneous operation: 669299
# Processing file: File_185...
# Minimum segment length for File_185 in Simultaneous operation: 669563
# Processing file: File_186...
# Minimum segment length for File_186 in Simultaneous operation: 669944
# Processing file: File_187...
# Minimum segment length for File_187 in Simultaneous operation: 670627
# Processing file: File_188...
# Minimum segment length for File_188 in Simultaneous operation: 669165
# Processing file: File_189...
# Minimum segment length for File_189 in Simultaneous operation: 670080
# Processing file: File_205...
# Minimum segment length for File_205 in Simultaneous operation: 670317
# Processing file: File_206...
# Minimum segment length for File_206 in Simultaneous operation: 671448
# Processing file: File_207...
# Minimum segment length for File_207 in Simultaneous operation: 672108
# Processing file: File_208...
# Minimum segment length for File_208 in Simultaneous operation: 671863
# Processing file: File_209...
# Minimum segment length for File_209 in Simultaneous operation: 671390
# Processing file: File_210...
# Minimum segment length for File_210 in Simultaneous operation: 670981
# Processing file: File_211...
# Minimum segment length for File_211 in Simultaneous operation: 670963
# Processing file: File_212...
# Minimum segment length for File_212 in Simultaneous operation: 671888
# Processing file: File_213...
# Minimum segment length for File_213 in Simultaneous operation: 671604
# Processing file: File_214...
# Minimum segment length for File_214 in Simultaneous operation: 671239
# Processing file: File_215...
# Minimum segment length for File_215 in Simultaneous operation: 670732
# Processing file: File_216...
# Minimum segment length for File_216 in Simultaneous operation: 671477
# Processing file: File_217...
# Minimum segment length for File_217 in Simultaneous operation: 671454
# Processing file: File_218...
# Minimum segment length for File_218 in Simultaneous operation: 671103
# Processing file: File_219...
# Minimum segment length for File_219 in Simultaneous operation: 671459
# Processing file: File_235...
# Minimum segment length for File_235 in Simultaneous operation: 670739
# Processing file: File_236...
# Minimum segment length for File_236 in Simultaneous operation: 670244
# Processing file: File_237...
# Minimum segment length for File_237 in Simultaneous operation: 670181
# Processing file: File_238...
# Minimum segment length for File_238 in Simultaneous operation: 669307
# Processing file: File_239...
# Minimum segment length for File_239 in Simultaneous operation: 669659
# Processing file: File_240...
# Minimum segment length for File_240 in Simultaneous operation: 669415
# Processing file: File_241...
# Minimum segment length for File_241 in Simultaneous operation: 670911
# Processing file: File_242...
# Minimum segment length for File_242 in Simultaneous operation: 669658
# Processing file: File_243...
# Minimum segment length for File_243 in Simultaneous operation: 670332
# Processing file: File_244...
# Minimum segment length for File_244 in Simultaneous operation: 670270
# Processing file: File_245...
# Minimum segment length for File_245 in Simultaneous operation: 669712
# Processing file: File_246...
# Minimum segment length for File_246 in Simultaneous operation: 668936
# Processing file: File_247...
# Minimum segment length for File_247 in Simultaneous operation: 669923
# Processing file: File_248...
# Minimum segment length for File_248 in Simultaneous operation: 669831
# Processing file: File_249...
# Minimum segment length for File_249 in Simultaneous operation: 671190
# Processing file: File_265...
# Minimum segment length for File_265 in Simultaneous operation: 668491
# Processing file: File_266...
# Minimum segment length for File_266 in Simultaneous operation: 671237
# Processing file: File_267...
# Minimum segment length for File_267 in Simultaneous operation: 671809
# Processing file: File_268...
# Minimum segment length for File_268 in Simultaneous operation: 671305
# Processing file: File_269...
# Minimum segment length for File_269 in Simultaneous operation: 672095
# Processing file: File_270...
# Minimum segment length for File_270 in Simultaneous operation: 670890
# Processing file: File_271...
# Minimum segment length for File_271 in Simultaneous operation: 670866
# Processing file: File_272...
# Minimum segment length for File_272 in Simultaneous operation: 671194
# Processing file: File_273...
# Minimum segment length for File_273 in Simultaneous operation: 671022
# Processing file: File_274...
# Minimum segment length for File_274 in Simultaneous operation: 671155
# Processing file: File_275...
# Minimum segment length for File_275 in Simultaneous operation: 671872
# Processing file: File_276...
# Minimum segment length for File_276 in Simultaneous operation: 671305
# Processing file: File_277...
# Minimum segment length for File_277 in Simultaneous operation: 671988
# Processing file: File_278...
# Minimum segment length for File_278 in Simultaneous operation: 670667
# Processing file: File_279...
# Minimum segment length for File_279 in Simultaneous operation: 671994
# Processing file: File_295...
# Minimum segment length for File_295 in Simultaneous operation: 670696
# Processing file: File_296...
# Minimum segment length for File_296 in Simultaneous operation: 668755
# Processing file: File_297...
# Minimum segment length for File_297 in Simultaneous operation: 669685
# Processing file: File_298...
# Minimum segment length for File_298 in Simultaneous operation: 669043
# Processing file: File_299...
# Minimum segment length for File_299 in Simultaneous operation: 669621
# Processing file: File_300...
# Minimum segment length for File_300 in Simultaneous operation: 668934
# Processing file: File_301...
# Minimum segment length for File_301 in Simultaneous operation: 670357
# Processing file: File_302...
# Minimum segment length for File_302 in Simultaneous operation: 668841
# Processing file: File_303...
# Minimum segment length for File_303 in Simultaneous operation: 670510
# Processing file: File_304...
# Minimum segment length for File_304 in Simultaneous operation: 669017
# Processing file: File_305...
# Minimum segment length for File_305 in Simultaneous operation: 671425
# Processing file: File_306...
# Minimum segment length for File_306 in Simultaneous operation: 668662
# Processing file: File_307...
# Minimum segment length for File_307 in Simultaneous operation: 670284
# Processing file: File_308...
# Minimum segment length for File_308 in Simultaneous operation: 669906
# Processing file: File_309...
# Minimum segment length for File_309 in Simultaneous operation: 670429
# Processing file: File_325...
# Minimum segment length for File_325 in Simultaneous operation: 670590
# Processing file: File_326...
# Minimum segment length for File_326 in Simultaneous operation: 671253
# Processing file: File_327...
# Minimum segment length for File_327 in Simultaneous operation: 671705
# Processing file: File_328...
# Minimum segment length for File_328 in Simultaneous operation: 671472
# Processing file: File_329...
# Minimum segment length for File_329 in Simultaneous operation: 672699
# Processing file: File_330...
# Minimum segment length for File_330 in Simultaneous operation: 672239
# Processing file: File_331...
# Minimum segment length for File_331 in Simultaneous operation: 672325
# Processing file: File_332...
# Minimum segment length for File_332 in Simultaneous operation: 672902
# Processing file: File_333...
# Minimum segment length for File_333 in Simultaneous operation: 671682
# Processing file: File_334...
# Minimum segment length for File_334 in Simultaneous operation: 672104
# Processing file: File_335...
# Minimum segment length for File_335 in Simultaneous operation: 672521
# Processing file: File_336...
# Minimum segment length for File_336 in Simultaneous operation: 671402
# Processing file: File_337...
# Minimum segment length for File_337 in Simultaneous operation: 671839
# Processing file: File_338...
# Minimum segment length for File_338 in Simultaneous operation: 671668
# Processing file: File_339...
# Minimum segment length for File_339 in Simultaneous operation: 671402
# Processing file: File_355...
# Minimum segment length for File_355 in Simultaneous operation: 671424
# Processing file: File_356...
# Minimum segment length for File_356 in Simultaneous operation: 671458
# Processing file: File_357...
# Minimum segment length for File_357 in Simultaneous operation: 672794
# Processing file: File_358...
# Minimum segment length for File_358 in Simultaneous operation: 671272
# Processing file: File_359...
# Minimum segment length for File_359 in Simultaneous operation: 672402
# Processing file: File_360...
# Minimum segment length for File_360 in Simultaneous operation: 671853
# Processing file: File_361...
# Minimum segment length for File_361 in Simultaneous operation: 672481
# Processing file: File_362...
# Minimum segment length for File_362 in Simultaneous operation: 672142
# Processing file: File_363...
# Minimum segment length for File_363 in Simultaneous operation: 671435
# Processing file: File_364...
# Minimum segment length for File_364 in Simultaneous operation: 672042
# Processing file: File_365...
# Minimum segment length for File_365 in Simultaneous operation: 672118
# Processing file: File_366...
# Minimum segment length for File_366 in Simultaneous operation: 671818
# Processing file: File_367...
# Minimum segment length for File_367 in Simultaneous operation: 672125
# Processing file: File_368...
# Minimum segment length for File_368 in Simultaneous operation: 671668
# Processing file: File_369...
# Minimum segment length for File_369 in Simultaneous operation: 671656
# Processing file: File_385...
# Minimum segment length for File_385 in Simultaneous operation: 670896
# Processing file: File_386...
# Minimum segment length for File_386 in Simultaneous operation: 672454
# Processing file: File_387...
# Minimum segment length for File_387 in Simultaneous operation: 672472
# Processing file: File_388...
# Minimum segment length for File_388 in Simultaneous operation: 672085
# Processing file: File_389...
# Minimum segment length for File_389 in Simultaneous operation: 671129
# Processing file: File_390...
# Minimum segment length for File_390 in Simultaneous operation: 671657
# Processing file: File_391...
# Minimum segment length for File_391 in Simultaneous operation: 670516
# Processing file: File_392...
# Minimum segment length for File_392 in Simultaneous operation: 671676
# Processing file: File_393...
# Minimum segment length for File_393 in Simultaneous operation: 672538
# Processing file: File_394...
# Minimum segment length for File_394 in Simultaneous operation: 672323
# Processing file: File_395...
# Minimum segment length for File_395 in Simultaneous operation: 672407
# Processing file: File_396...
# Minimum segment length for File_396 in Simultaneous operation: 672499
# Processing file: File_397...
# Minimum segment length for File_397 in Simultaneous operation: 670664
# Processing file: File_398...
# Minimum segment length for File_398 in Simultaneous operation: 672313
# Processing file: File_399...
# Minimum segment length for File_399 in Simultaneous operation: 670419
# Global minimum segment length across all operations: 378986

# %%
import torch

# Given conditions
num_channels = 3  # The number of channels is always 3
win_len = 5000

how_many = global_min_length//win_len

# Initialize tensor with fixed dimensions
sim_tensor = torch.zeros(len(simultaneous_dict)*how_many, num_channels, win_len)

sim_file_names = list(simultaneous_dict.keys())
file_names = []

for file_name in sim_file_names:
    file_names.extend([file_name] * how_many)

# Function to trim or pad segments
def process_segment(segment, target_length):
    if len(segment) >= target_length:
        return segment[:target_length]
    else:
        # Example of padding, assuming segments are lists; adjust based on actual data type
        print('-----'*20)
        return segment + [0] * (target_length - len(segment))


current_tensor_index = 0  # Initialize an index to keep track of the current position in sim_tensor

offset = 0
for i, (file_name, file_data) in enumerate(simultaneous_dict.items()):
    for j, (channel_name, channel_data) in enumerate(file_data['channels'].items()):
        processed_segment = process_segment(channel_data['segment'][0], global_min_length)
        
        # Slice every channel segment into subsegments
        for k in range(how_many):
            start_idx = k * win_len
            end_idx = start_idx + win_len
            subsegment = processed_segment[start_idx:end_idx]
            
            # Assign the subsegment correctly to sim_tensor
            if len(subsegment) != win_len:  
                print('Oh, no!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!') #Throw an error instead
                
            sim_tensor[offset+k, j, :] = torch.tensor(subsegment, dtype=torch.float32).view(1, 1, -1)
    offset += how_many


# Define mode descriptions with repetition for each how_many times
mode_descriptions = []

for _, file_data in simultaneous_dict.items():
    mode_tuple = (file_data['Cube 1 Mode'], file_data['Cube 2 Mode'])
    mode_descriptions.extend([mode_tuple] * how_many)

# %%
sim_tensor.shape
# Out:
# torch.Size([15000, 3, 5000])

# %%
len(file_names), len(mode_descriptions)
# Out:
# (15000, 15000)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import random

# Extract 30 random indexes from 0 to the size of sim_tensor's first dimension
max_idx = sim_tensor.shape[0]  # Adjusted to the actual size of sim_tensor
random_indexes = random.sample(range(max_idx), 30)

# Channel names based on the given descriptions
channel_names = {
    0: "Flat response microphone (front)",
    1: "Flat response microphone (rear)",
    2: "Resonant microphone"
}

# Sampling frequency for the time vector calculation
Fs = 200000  # 200kHz

# Iterate over the selected random indexes
for idx in random_indexes:
    sim_data = sim_tensor[idx]
    file_name_sim = file_names[idx]
    mode_desc = mode_descriptions[idx]

    # Number of samples in each signal
    N = sim_data.shape[-1]  # Using the last dimension as the number of samples
    time_vector = np.linspace(0, N / Fs, N, endpoint=False)  # Time vector for plotting
    
    # Plotting
    fig, axs = plt.subplots(3, 1, figsize=(10, 7))  # 3 channels, 1 column for sim
    fig.suptitle(f"Sim: {file_name_sim}, Modes: {mode_desc}")
    
    for channel_idx in range(3):  
        # Plot simultaneous data
        axs[channel_idx].plot(time_vector, sim_data[channel_idx, :].numpy(), label=f"Sim Channel {channel_idx+1}")

        # Set titles and labels
        axs[channel_idx].set_title(f"Simultaneous - {channel_names[channel_idx]}")
        axs[channel_idx].set_xlabel("Time (s)")
        axs[channel_idx].set_ylabel("Amplitude (V)")
        axs[channel_idx].legend()
    
    # Adjust layout
    plt.tight_layout()
    plt.show()

# %%
# Packaging the data into a dictionary
data_package = {
    "sim_tensor": sim_tensor,
    "file_names": file_names,
    "mode_descriptions": mode_descriptions,
}

import os
import pickle

data_folder = "./Data"
os.makedirs(data_folder, exist_ok=True)

with open(os.path.join(data_folder, "pytorch_database_short.pkl"), "wb") as f:
    pickle.dump(data_package, f)
