# %%
from utils import load_and_convert_to_dataframe, highlight_max_accuracy

# %% [markdown]
# # Results for simultaneous mode

# %% [markdown]
# ## Using all sensors

# %%
# Use the function to load the file, extract data, and convert to DataFrame
file_path = './Sim_all.txt'
df = load_and_convert_to_dataframe(file_path)

# Highlight the highest Overall Accuracy row in bold
df_styled = df.style.apply(highlight_max_accuracy, subset=['Overall Accuracy'])
df_styled
# Out:
# <style type="text/css">
# #T_522a2_row4_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_522a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_522a2_level0_col0" class="col_heading level0 col0" >LR</th>
#       <th id="T_522a2_level0_col1" class="col_heading level0 col1" >Weight Decay</th>
#       <th id="T_522a2_level0_col2" class="col_heading level0 col2" >Filter Size</th>
#       <th id="T_522a2_level0_col3" class="col_heading level0 col3" >Output 1 Accuracy</th>
#       <th id="T_522a2_level0_col4" class="col_heading level0 col4" >Output 2 Accuracy</th>
#       <th id="T_522a2_level0_col5" class="col_heading level0 col5" >Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_522a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_522a2_row0_col0" class="data row0 col0" >0.001</td>
#       <td id="T_522a2_row0_col1" class="data row0 col1" >0.001</td>
# ...

# %% [markdown]
# ## Excluding the resonant sensor

# %%
# Use the function to load the file, extract data, and convert to DataFrame
file_path = './Sim_no_resonant.txt'
df = load_and_convert_to_dataframe(file_path)

# Highlight the highest Overall Accuracy row in bold
df_styled = df.style.apply(highlight_max_accuracy, subset=['Overall Accuracy'])
df_styled
# Out:
# <style type="text/css">
# #T_1dd51_row1_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_1dd51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dd51_level0_col0" class="col_heading level0 col0" >LR</th>
#       <th id="T_1dd51_level0_col1" class="col_heading level0 col1" >Weight Decay</th>
#       <th id="T_1dd51_level0_col2" class="col_heading level0 col2" >Filter Size</th>
#       <th id="T_1dd51_level0_col3" class="col_heading level0 col3" >Output 1 Accuracy</th>
#       <th id="T_1dd51_level0_col4" class="col_heading level0 col4" >Output 2 Accuracy</th>
#       <th id="T_1dd51_level0_col5" class="col_heading level0 col5" >Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dd51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1dd51_row0_col0" class="data row0 col0" >0.001</td>
#       <td id="T_1dd51_row0_col1" class="data row0 col1" >0.001</td>
# ...

# %% [markdown]
# ## Only rear microphone

# %%
# Use the function to load the file, extract data, and convert to DataFrame
file_path = './Sim_only_back.txt'
df = load_and_convert_to_dataframe(file_path)

# Highlight the highest Overall Accuracy row in bold
df_styled = df.style.apply(highlight_max_accuracy, subset=['Overall Accuracy'])
df_styled
# Out:
# <style type="text/css">
# #T_fa0e9_row2_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_fa0e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa0e9_level0_col0" class="col_heading level0 col0" >LR</th>
#       <th id="T_fa0e9_level0_col1" class="col_heading level0 col1" >Weight Decay</th>
#       <th id="T_fa0e9_level0_col2" class="col_heading level0 col2" >Filter Size</th>
#       <th id="T_fa0e9_level0_col3" class="col_heading level0 col3" >Output 1 Accuracy</th>
#       <th id="T_fa0e9_level0_col4" class="col_heading level0 col4" >Output 2 Accuracy</th>
#       <th id="T_fa0e9_level0_col5" class="col_heading level0 col5" >Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa0e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa0e9_row0_col0" class="data row0 col0" >0.001</td>
#       <td id="T_fa0e9_row0_col1" class="data row0 col1" >0.001</td>
# ...

# %% [markdown]
# ## Only front microphone

# %%
# Use the function to load the file, extract data, and convert to DataFrame
file_path = './Sim_only_front.txt'
df = load_and_convert_to_dataframe(file_path)

# Highlight the highest Overall Accuracy row in bold
df_styled = df.style.apply(highlight_max_accuracy, subset=['Overall Accuracy'])
df_styled
# Out:
# <style type="text/css">
# #T_daff6_row7_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_daff6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_daff6_level0_col0" class="col_heading level0 col0" >LR</th>
#       <th id="T_daff6_level0_col1" class="col_heading level0 col1" >Weight Decay</th>
#       <th id="T_daff6_level0_col2" class="col_heading level0 col2" >Filter Size</th>
#       <th id="T_daff6_level0_col3" class="col_heading level0 col3" >Output 1 Accuracy</th>
#       <th id="T_daff6_level0_col4" class="col_heading level0 col4" >Output 2 Accuracy</th>
#       <th id="T_daff6_level0_col5" class="col_heading level0 col5" >Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daff6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_daff6_row0_col0" class="data row0 col0" >0.001</td>
#       <td id="T_daff6_row0_col1" class="data row0 col1" >0.001</td>
# ...

# %% [markdown]
# ## Only resonant microphone

# %%
# Use the function to load the file, extract data, and convert to DataFrame
file_path = './Sim_only_resonant.txt'
df = load_and_convert_to_dataframe(file_path)

# Highlight the highest Overall Accuracy row in bold
df_styled = df.style.apply(highlight_max_accuracy, subset=['Overall Accuracy'])
df_styled
# Out:
# <style type="text/css">
# #T_18f8f_row7_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_18f8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18f8f_level0_col0" class="col_heading level0 col0" >LR</th>
#       <th id="T_18f8f_level0_col1" class="col_heading level0 col1" >Weight Decay</th>
#       <th id="T_18f8f_level0_col2" class="col_heading level0 col2" >Filter Size</th>
#       <th id="T_18f8f_level0_col3" class="col_heading level0 col3" >Output 1 Accuracy</th>
#       <th id="T_18f8f_level0_col4" class="col_heading level0 col4" >Output 2 Accuracy</th>
#       <th id="T_18f8f_level0_col5" class="col_heading level0 col5" >Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18f8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18f8f_row0_col0" class="data row0 col0" >0.001</td>
#       <td id="T_18f8f_row0_col1" class="data row0 col1" >0.001</td>
# ...
