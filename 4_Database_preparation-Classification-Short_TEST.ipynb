# %%
import pickle

file_name = 'my_dic_TEST.pkl'
    
# Open the file and load its content
with open(file_name, 'rb') as file:
    data_dict = pickle.load(file)
    
# Print all the keys
print("Combined dictionary keys:", len(data_dict.keys()))
# Out:
# Combined dictionary keys: 160

# %%
data_dict.keys()
# Out:
# dict_keys(['File_0', 'File_1', 'File_2', 'File_3', 'File_4', 'File_5', 'File_6', 'File_7', 'File_8', 'File_9', 'File_10', 'File_11', 'File_12', 'File_13', 'File_14', 'File_15', 'File_16', 'File_17', 'File_18', 'File_19', 'File_20', 'File_21', 'File_22', 'File_23', 'File_24', 'File_25', 'File_26', 'File_27', 'File_28', 'File_29', 'File_30', 'File_31', 'File_32', 'File_33', 'File_34', 'File_35', 'File_36', 'File_37', 'File_38', 'File_39', 'File_40', 'File_41', 'File_42', 'File_43', 'File_44', 'File_45', 'File_46', 'File_47', 'File_48', 'File_49', 'File_50', 'File_51', 'File_52', 'File_53', 'File_54', 'File_55', 'File_56', 'File_57', 'File_58', 'File_59', 'File_60', 'File_61', 'File_62', 'File_63', 'File_64', 'File_65', 'File_66', 'File_67', 'File_68', 'File_69', 'File_70', 'File_71', 'File_72', 'File_73', 'File_74', 'File_75', 'File_76', 'File_77', 'File_78', 'File_79', 'File_80', 'File_81', 'File_82', 'File_83', 'File_84', 'File_85', 'File_86', 'File_87', 'File_88', 'File_89', 'File_90', 'File_91', 'File_92', 'File_93', 'File_94', 'File_95', 'File_96', 'File_97', 'File_98', 'File_99', 'File_100', 'File_101', 'File_102', 'File_103', 'File_104', 'File_105', 'File_106', 'File_107', 'File_108', 'File_109', 'File_110', 'File_111', 'File_112', 'File_113', 'File_114', 'File_115', 'File_116', 'File_117', 'File_118', 'File_119', 'File_120', 'File_121', 'File_122', 'File_123', 'File_124', 'File_125', 'File_126', 'File_127', 'File_128', 'File_129', 'File_130', 'File_131', 'File_132', 'File_133', 'File_134', 'File_135', 'File_136', 'File_137', 'File_138', 'File_139', 'File_140', 'File_141', 'File_142', 'File_143', 'File_144', 'File_145', 'File_146', 'File_147', 'File_148', 'File_149', 'File_150', 'File_151', 'File_152', 'File_153', 'File_154', 'File_155', 'File_156', 'File_157', 'File_158', 'File_159'])

# %%
data_dict['File_144']
# Out:
# {'Channel_1': {'Operation': 'Sequential',
#   'Cube 1 Mode': 'Keyhole 4',
#   'Cube 2 Mode': 'Keyhole 4',
#   'segments': [array([1.885529 , 1.63269  , 1.411438 , ..., 0.4020691, 1.739044 ,
#           1.77597  ]),
#    array([1.992645 , 0.140686 , 0.3395081, ..., 0.4455566, 1.380615 ,
#           1.577606 ])],
#   'boundaries': (array([ 19511, 893595]), array([ 689770, 1564131])),
#   'avg_length': 670398.5,
#   'std_dev': 138.5,
#   'num_segments': 2},
#  'Channel_2': {'Operation': 'Sequential',
#   'Cube 1 Mode': 'Keyhole 4',
#   'Cube 2 Mode': 'Keyhole 4',
#   'segments': [array([ 1.747742 ,  0.6225586,  0.2503967, ..., -0.5958557,  0.9931946,
#            1.608124 ]),
#    array([ 1.625214 ,  1.439514 ,  1.277466 , ..., -0.2064514,  0.6776428,
#            1.5625   ])],
#   'boundaries': (array([ 19515, 893441]), array([ 689172, 1563187])),
#   'avg_length': 669702.5,
#   'std_dev': 44.5,
#   'num_segments': 2},
#  'Channel_3': {'Operation': 'Sequential',
#   'Cube 1 Mode': 'Keyhole 4',
#   'Cube 2 Mode': 'Keyhole 4',
#   'segments': [array([-0.01953125, -0.00396729,  0.00030518, ..., -0.01617432,
#           -0.00808716,  0.00793457]),
#    array([-0.05020142, -0.04211426, -0.02120972, ...,  0.00152588,
#           -0.00366211, -0.00076294])],
#   'boundaries': (array([ 19515, 893441]), array([ 689172, 1563187])),
#   'avg_length': 669702.5,
#   'std_dev': 44.5,
#   'num_segments': 2}}

# %%
sequential_dict = {}
simultaneous_dict = {}

# Loop over all files
for file_name, file_data in data_dict.items():
    print(f"Processing {file_name}...")
    for channel_name, channel_data in file_data.items():

        segments = channel_data['segments']
        mode1 = channel_data['Cube 1 Mode']
        mode2 = channel_data['Cube 2 Mode']

        # Check operation type and update the respective dictionary
        if channel_data['Operation'] == 'Sequential':
            if file_name not in sequential_dict:
                sequential_dict[file_name] = {'Cube 1 Mode': mode1, 'Cube 2 Mode': mode2, 'channels': {}}
            
            # Only update channel specific data under the 'channels' sub-dictionary
            sequential_dict[file_name]['channels'][channel_name] = {'segment': segments}

        elif channel_data['Operation'] == 'Simultaneous':
            if file_name not in simultaneous_dict:
                simultaneous_dict[file_name] = {'Cube 1 Mode': mode1, 'Cube 2 Mode': mode2, 'channels': {}}
            
            # Only update channel specific data under the 'channels' sub-dictionary
            simultaneous_dict[file_name]['channels'][channel_name] = {'segment': segments}
# Out:
# Processing File_0...
# Processing File_1...
# Processing File_2...
# Processing File_3...
# Processing File_4...
# Processing File_5...
# Processing File_6...
# Processing File_7...
# Processing File_8...
# Processing File_9...
# Processing File_10...
# Processing File_11...
# Processing File_12...
# Processing File_13...
# Processing File_14...
# Processing File_15...
# Processing File_16...
# Processing File_17...
# Processing File_18...
# Processing File_19...
# Processing File_20...
# Processing File_21...
# Processing File_22...
# Processing File_23...
# Processing File_24...
# Processing File_25...
# Processing File_26...
# Processing File_27...
# Processing File_28...
# Processing File_29...
# Processing File_30...
# Processing File_31...
# Processing File_32...
# Processing File_33...
# Processing File_34...
# Processing File_35...
# Processing File_36...
# Processing File_37...
# Processing File_38...
# Processing File_39...
# Processing File_40...
# Processing File_41...
# Processing File_42...
# Processing File_43...
# Processing File_44...
# Processing File_45...
# Processing File_46...
# Processing File_47...
# Processing File_48...
# Processing File_49...
# Processing File_50...
# Processing File_51...
# Processing File_52...
# Processing File_53...
# Processing File_54...
# Processing File_55...
# Processing File_56...
# Processing File_57...
# Processing File_58...
# Processing File_59...
# Processing File_60...
# Processing File_61...
# Processing File_62...
# Processing File_63...
# Processing File_64...
# Processing File_65...
# Processing File_66...
# Processing File_67...
# Processing File_68...
# Processing File_69...
# Processing File_70...
# Processing File_71...
# Processing File_72...
# Processing File_73...
# Processing File_74...
# Processing File_75...
# Processing File_76...
# Processing File_77...
# Processing File_78...
# Processing File_79...
# Processing File_80...
# Processing File_81...
# Processing File_82...
# Processing File_83...
# Processing File_84...
# Processing File_85...
# Processing File_86...
# Processing File_87...
# Processing File_88...
# Processing File_89...
# Processing File_90...
# Processing File_91...
# Processing File_92...
# Processing File_93...
# Processing File_94...
# Processing File_95...
# Processing File_96...
# Processing File_97...
# Processing File_98...
# Processing File_99...
# Processing File_100...
# Processing File_101...
# Processing File_102...
# Processing File_103...
# Processing File_104...
# Processing File_105...
# Processing File_106...
# Processing File_107...
# Processing File_108...
# Processing File_109...
# Processing File_110...
# Processing File_111...
# Processing File_112...
# Processing File_113...
# Processing File_114...
# Processing File_115...
# Processing File_116...
# Processing File_117...
# Processing File_118...
# Processing File_119...
# Processing File_120...
# Processing File_121...
# Processing File_122...
# Processing File_123...
# Processing File_124...
# Processing File_125...
# Processing File_126...
# Processing File_127...
# Processing File_128...
# Processing File_129...
# Processing File_130...
# Processing File_131...
# Processing File_132...
# Processing File_133...
# Processing File_134...
# Processing File_135...
# Processing File_136...
# Processing File_137...
# Processing File_138...
# Processing File_139...
# Processing File_140...
# Processing File_141...
# Processing File_142...
# Processing File_143...
# Processing File_144...
# Processing File_145...
# Processing File_146...
# Processing File_147...
# Processing File_148...
# Processing File_149...
# Processing File_150...
# Processing File_151...
# Processing File_152...
# Processing File_153...
# Processing File_154...
# Processing File_155...
# Processing File_156...
# Processing File_157...
# Processing File_158...
# Processing File_159...

# %%
# Create iterators for both dictionaries
sequential_iter = iter(sequential_dict.items())
simultaneous_iter = iter(simultaneous_dict.items())

# Loop until we run out of items in either dictionary
while True:
    try:
        # Get the next item from both dictionaries
        seq_file, seq_data = next(sequential_iter)
        sim_file, sim_data = next(simultaneous_iter)

        # Compare Cube 1 Mode and Cube 2 Mode between the sequential and simultaneous file
        seq_mode1, seq_mode2 = seq_data['Cube 1 Mode'], seq_data['Cube 2 Mode']
        sim_mode1, sim_mode2 = sim_data['Cube 1 Mode'], sim_data['Cube 2 Mode']

        # Check if modes correspond
        modes_correspond = (seq_mode1 == sim_mode1) and (seq_mode2 == sim_mode2)
        print(f"Comparing {seq_file} (Sequential) and {sim_file} (Simultaneous): Modes correspond? {modes_correspond}")

    except StopIteration:
        # One of the dictionaries has been fully iterated
        break
# Out:
# Comparing File_0 (Sequential) and File_10 (Simultaneous): Modes correspond? True
# Comparing File_1 (Sequential) and File_11 (Simultaneous): Modes correspond? True
# Comparing File_2 (Sequential) and File_12 (Simultaneous): Modes correspond? True
# Comparing File_3 (Sequential) and File_13 (Simultaneous): Modes correspond? True
# Comparing File_4 (Sequential) and File_14 (Simultaneous): Modes correspond? True
# Comparing File_5 (Sequential) and File_15 (Simultaneous): Modes correspond? True
# Comparing File_6 (Sequential) and File_16 (Simultaneous): Modes correspond? True
# Comparing File_7 (Sequential) and File_17 (Simultaneous): Modes correspond? True
# Comparing File_8 (Sequential) and File_18 (Simultaneous): Modes correspond? True
# Comparing File_9 (Sequential) and File_19 (Simultaneous): Modes correspond? True
# Comparing File_20 (Sequential) and File_30 (Simultaneous): Modes correspond? True
# Comparing File_21 (Sequential) and File_31 (Simultaneous): Modes correspond? True
# Comparing File_22 (Sequential) and File_32 (Simultaneous): Modes correspond? True
# Comparing File_23 (Sequential) and File_33 (Simultaneous): Modes correspond? True
# Comparing File_24 (Sequential) and File_34 (Simultaneous): Modes correspond? True
# Comparing File_25 (Sequential) and File_35 (Simultaneous): Modes correspond? True
# Comparing File_26 (Sequential) and File_36 (Simultaneous): Modes correspond? True
# Comparing File_27 (Sequential) and File_37 (Simultaneous): Modes correspond? True
# Comparing File_28 (Sequential) and File_38 (Simultaneous): Modes correspond? True
# Comparing File_29 (Sequential) and File_39 (Simultaneous): Modes correspond? True
# Comparing File_40 (Sequential) and File_55 (Simultaneous): Modes correspond? True
# Comparing File_41 (Sequential) and File_56 (Simultaneous): Modes correspond? True
# Comparing File_42 (Sequential) and File_57 (Simultaneous): Modes correspond? True
# Comparing File_43 (Sequential) and File_58 (Simultaneous): Modes correspond? True
# Comparing File_44 (Sequential) and File_59 (Simultaneous): Modes correspond? True
# Comparing File_45 (Sequential) and File_60 (Simultaneous): Modes correspond? True
# Comparing File_46 (Sequential) and File_61 (Simultaneous): Modes correspond? True
# Comparing File_47 (Sequential) and File_62 (Simultaneous): Modes correspond? True
# Comparing File_48 (Sequential) and File_63 (Simultaneous): Modes correspond? True
# Comparing File_49 (Sequential) and File_64 (Simultaneous): Modes correspond? True
# Comparing File_50 (Sequential) and File_65 (Simultaneous): Modes correspond? True
# Comparing File_51 (Sequential) and File_66 (Simultaneous): Modes correspond? True
# Comparing File_52 (Sequential) and File_67 (Simultaneous): Modes correspond? True
# Comparing File_53 (Sequential) and File_68 (Simultaneous): Modes correspond? True
# Comparing File_54 (Sequential) and File_69 (Simultaneous): Modes correspond? True
# Comparing File_70 (Sequential) and File_85 (Simultaneous): Modes correspond? True
# Comparing File_71 (Sequential) and File_86 (Simultaneous): Modes correspond? True
# Comparing File_72 (Sequential) and File_87 (Simultaneous): Modes correspond? True
# Comparing File_73 (Sequential) and File_88 (Simultaneous): Modes correspond? True
# Comparing File_74 (Sequential) and File_89 (Simultaneous): Modes correspond? True
# Comparing File_75 (Sequential) and File_90 (Simultaneous): Modes correspond? True
# Comparing File_76 (Sequential) and File_91 (Simultaneous): Modes correspond? True
# Comparing File_77 (Sequential) and File_92 (Simultaneous): Modes correspond? True
# Comparing File_78 (Sequential) and File_93 (Simultaneous): Modes correspond? True
# Comparing File_79 (Sequential) and File_94 (Simultaneous): Modes correspond? True
# Comparing File_80 (Sequential) and File_95 (Simultaneous): Modes correspond? True
# Comparing File_81 (Sequential) and File_96 (Simultaneous): Modes correspond? True
# Comparing File_82 (Sequential) and File_97 (Simultaneous): Modes correspond? True
# Comparing File_83 (Sequential) and File_98 (Simultaneous): Modes correspond? True
# Comparing File_84 (Sequential) and File_99 (Simultaneous): Modes correspond? True
# Comparing File_100 (Sequential) and File_115 (Simultaneous): Modes correspond? True
# Comparing File_101 (Sequential) and File_116 (Simultaneous): Modes correspond? True
# Comparing File_102 (Sequential) and File_117 (Simultaneous): Modes correspond? True
# Comparing File_103 (Sequential) and File_118 (Simultaneous): Modes correspond? True
# Comparing File_104 (Sequential) and File_119 (Simultaneous): Modes correspond? True
# Comparing File_105 (Sequential) and File_120 (Simultaneous): Modes correspond? True
# Comparing File_106 (Sequential) and File_121 (Simultaneous): Modes correspond? True
# Comparing File_107 (Sequential) and File_122 (Simultaneous): Modes correspond? True
# Comparing File_108 (Sequential) and File_123 (Simultaneous): Modes correspond? True
# Comparing File_109 (Sequential) and File_124 (Simultaneous): Modes correspond? True
# Comparing File_110 (Sequential) and File_125 (Simultaneous): Modes correspond? True
# Comparing File_111 (Sequential) and File_126 (Simultaneous): Modes correspond? True
# Comparing File_112 (Sequential) and File_127 (Simultaneous): Modes correspond? True
# Comparing File_113 (Sequential) and File_128 (Simultaneous): Modes correspond? True
# Comparing File_114 (Sequential) and File_129 (Simultaneous): Modes correspond? True
# Comparing File_130 (Sequential) and File_145 (Simultaneous): Modes correspond? True
# Comparing File_131 (Sequential) and File_146 (Simultaneous): Modes correspond? True
# Comparing File_132 (Sequential) and File_147 (Simultaneous): Modes correspond? True
# Comparing File_133 (Sequential) and File_148 (Simultaneous): Modes correspond? True
# Comparing File_134 (Sequential) and File_149 (Simultaneous): Modes correspond? True
# Comparing File_135 (Sequential) and File_150 (Simultaneous): Modes correspond? True
# Comparing File_136 (Sequential) and File_151 (Simultaneous): Modes correspond? True
# Comparing File_137 (Sequential) and File_152 (Simultaneous): Modes correspond? True
# Comparing File_138 (Sequential) and File_153 (Simultaneous): Modes correspond? True
# Comparing File_139 (Sequential) and File_154 (Simultaneous): Modes correspond? True
# Comparing File_140 (Sequential) and File_155 (Simultaneous): Modes correspond? True
# Comparing File_141 (Sequential) and File_156 (Simultaneous): Modes correspond? True
# Comparing File_142 (Sequential) and File_157 (Simultaneous): Modes correspond? True
# Comparing File_143 (Sequential) and File_158 (Simultaneous): Modes correspond? True
# Comparing File_144 (Sequential) and File_159 (Simultaneous): Modes correspond? True

# %%
sequential_dict['File_0']
# Out:
# {'Cube 1 Mode': 'Conduction 2',
#  'Cube 2 Mode': 'Conduction 2',
#  'channels': {'Channel_1': {'segment': [array([1.81488  , 1.01944  , 1.442719 , ..., 0.3215027, 1.390533 ,
#            1.661987 ]),
#     array([1.871948 , 1.612396 , 1.399994 , ..., 0.1170349, 1.177979 ,
#            1.594849 ])]},
#   'Channel_2': {'segment': [array([1.619873 , 1.431427 , 0.2638245, ..., 0.8740234, 1.404266 ,
#            1.564789 ]),
#     array([1.873932 , 1.650391 , 1.460724 , ..., 0.2584839, 1.095734 ,
#            1.562653 ])]},
#   'Channel_3': {'segment': [array([ 0.00701904,  0.0012207 , -0.00549316, ..., -0.00549316,
#            -0.00747681, -0.00167847]),
#     array([-0.06378174, -0.04348755, -0.00686645, ..., -0.00015259,
#             0.00686645, -0.00106811])]}}}

# %%
# Initialize variables to track the minimum segment lengths
min_lengths = []

# Process each dictionary separately due to their differing structures and needs
for operation_dict, operation_type in zip([sequential_dict, simultaneous_dict], ['Sequential', 'Simultaneous']):
    print(f"Processing {operation_type} data")

    for file_name, file_data in operation_dict.items():
        print(f"Processing file: {file_name}...")

        # Initialize lists to store segments and their descriptions
        segments = []
        descriptions = []

        # Differing processing logic based on operation type
        if operation_type == 'Sequential':
            for channel_name, channel_data in file_data['channels'].items():
                for idx, seg in enumerate(channel_data['segment']):
                    segments.append(seg)
                    mode = file_data['Cube 1 Mode'] if idx == 0 else file_data['Cube 2 Mode']
                    descriptions.append(f"Channel: {channel_name}, Mode: {mode}")
        
        elif operation_type == 'Simultaneous':
            for channel_name, channel_data in file_data['channels'].items():
                segments.extend(channel_data['segment'])
                description = f"Channel: {channel_name}, Modes: {file_data['Cube 1 Mode']} & {file_data['Cube 2 Mode']}"
                descriptions.extend([description] * len(channel_data['segment']))
        
        # After processing each file, find the minimum segment length for the file
        if segments:  # Ensure there are segments processed before attempting to find the minimum
            min_length = min(len(seg) for seg in segments)
            min_lengths.append(min_length)
            print(f"Minimum segment length for {file_name} in {operation_type} operation: {min_length}")

# Find the global minimum segment length across all files and operation types
if min_lengths:  # Ensure there are minimum lengths calculated before attempting to find the global minimum
    global_min_length = min(min_lengths)
    print(f"Global minimum segment length across all operations: {global_min_length}")
else:
    print("No segment lengths were found to calculate a global minimum.")
# Out:
# Processing Sequential data
# Processing file: File_0...
# Minimum segment length for File_0 in Sequential operation: 426121
# Processing file: File_1...
# Minimum segment length for File_1 in Sequential operation: 426358
# Processing file: File_2...
# Minimum segment length for File_2 in Sequential operation: 426891
# Processing file: File_3...
# Minimum segment length for File_3 in Sequential operation: 425672
# Processing file: File_4...
# Minimum segment length for File_4 in Sequential operation: 426754
# Processing file: File_5...
# Minimum segment length for File_5 in Sequential operation: 424884
# Processing file: File_6...
# Minimum segment length for File_6 in Sequential operation: 425992
# Processing file: File_7...
# Minimum segment length for File_7 in Sequential operation: 425014
# Processing file: File_8...
# Minimum segment length for File_8 in Sequential operation: 425000
# Processing file: File_9...
# Minimum segment length for File_9 in Sequential operation: 424924
# Processing file: File_20...
# Minimum segment length for File_20 in Sequential operation: 425677
# Processing file: File_21...
# Minimum segment length for File_21 in Sequential operation: 423833
# Processing file: File_22...
# Minimum segment length for File_22 in Sequential operation: 424790
# Processing file: File_23...
# Minimum segment length for File_23 in Sequential operation: 423917
# Processing file: File_24...
# Minimum segment length for File_24 in Sequential operation: 425167
# Processing file: File_25...
# Minimum segment length for File_25 in Sequential operation: 423969
# Processing file: File_26...
# Minimum segment length for File_26 in Sequential operation: 425105
# Processing file: File_27...
# Minimum segment length for File_27 in Sequential operation: 424330
# Processing file: File_28...
# Minimum segment length for File_28 in Sequential operation: 425331
# Processing file: File_29...
# Minimum segment length for File_29 in Sequential operation: 424093
# Processing file: File_40...
# Minimum segment length for File_40 in Sequential operation: 401711
# Processing file: File_41...
# Minimum segment length for File_41 in Sequential operation: 400058
# Processing file: File_42...
# Minimum segment length for File_42 in Sequential operation: 400770
# Processing file: File_43...
# Minimum segment length for File_43 in Sequential operation: 400279
# Processing file: File_44...
# Minimum segment length for File_44 in Sequential operation: 401217
# Processing file: File_45...
# Minimum segment length for File_45 in Sequential operation: 400052
# Processing file: File_46...
# Minimum segment length for File_46 in Sequential operation: 400969
# Processing file: File_47...
# Minimum segment length for File_47 in Sequential operation: 400221
# Processing file: File_48...
# Minimum segment length for File_48 in Sequential operation: 400778
# Processing file: File_49...
# Minimum segment length for File_49 in Sequential operation: 399390
# Processing file: File_50...
# Minimum segment length for File_50 in Sequential operation: 400652
# Processing file: File_51...
# Minimum segment length for File_51 in Sequential operation: 400200
# Processing file: File_52...
# Minimum segment length for File_52 in Sequential operation: 400888
# Processing file: File_53...
# Minimum segment length for File_53 in Sequential operation: 400828
# Processing file: File_54...
# Minimum segment length for File_54 in Sequential operation: 401322
# Processing file: File_70...
# Minimum segment length for File_70 in Sequential operation: 400967
# Processing file: File_71...
# Minimum segment length for File_71 in Sequential operation: 401625
# Processing file: File_72...
# Minimum segment length for File_72 in Sequential operation: 402341
# Processing file: File_73...
# Minimum segment length for File_73 in Sequential operation: 400851
# Processing file: File_74...
# Minimum segment length for File_74 in Sequential operation: 400689
# Processing file: File_75...
# Minimum segment length for File_75 in Sequential operation: 400824
# Processing file: File_76...
# Minimum segment length for File_76 in Sequential operation: 401208
# Processing file: File_77...
# Minimum segment length for File_77 in Sequential operation: 401545
# Processing file: File_78...
# Minimum segment length for File_78 in Sequential operation: 401173
# Processing file: File_79...
# Minimum segment length for File_79 in Sequential operation: 401348
# Processing file: File_80...
# Minimum segment length for File_80 in Sequential operation: 400837
# Processing file: File_81...
# Minimum segment length for File_81 in Sequential operation: 400966
# Processing file: File_82...
# Minimum segment length for File_82 in Sequential operation: 400512
# Processing file: File_83...
# Minimum segment length for File_83 in Sequential operation: 402124
# Processing file: File_84...
# Minimum segment length for File_84 in Sequential operation: 400948
# Processing file: File_100...
# Minimum segment length for File_100 in Sequential operation: 401065
# Processing file: File_101...
# Minimum segment length for File_101 in Sequential operation: 399838
# Processing file: File_102...
# Minimum segment length for File_102 in Sequential operation: 402677
# Processing file: File_103...
# Minimum segment length for File_103 in Sequential operation: 400038
# Processing file: File_104...
# Minimum segment length for File_104 in Sequential operation: 401792
# Processing file: File_105...
# Minimum segment length for File_105 in Sequential operation: 400185
# Processing file: File_106...
# Minimum segment length for File_106 in Sequential operation: 402553
# Processing file: File_107...
# Minimum segment length for File_107 in Sequential operation: 399853
# Processing file: File_108...
# Minimum segment length for File_108 in Sequential operation: 402217
# Processing file: File_109...
# Minimum segment length for File_109 in Sequential operation: 400031
# Processing file: File_110...
# Minimum segment length for File_110 in Sequential operation: 402057
# Processing file: File_111...
# Minimum segment length for File_111 in Sequential operation: 399612
# Processing file: File_112...
# Minimum segment length for File_112 in Sequential operation: 401605
# Processing file: File_113...
# Minimum segment length for File_113 in Sequential operation: 400204
# Processing file: File_114...
# Minimum segment length for File_114 in Sequential operation: 402181
# Processing file: File_130...
# Minimum segment length for File_130 in Sequential operation: 670658
# Processing file: File_131...
# Minimum segment length for File_131 in Sequential operation: 669324
# Processing file: File_132...
# Minimum segment length for File_132 in Sequential operation: 668840
# Processing file: File_133...
# Minimum segment length for File_133 in Sequential operation: 668786
# Processing file: File_134...
# Minimum segment length for File_134 in Sequential operation: 669124
# Processing file: File_135...
# Minimum segment length for File_135 in Sequential operation: 668721
# Processing file: File_136...
# Minimum segment length for File_136 in Sequential operation: 669097
# Processing file: File_137...
# Minimum segment length for File_137 in Sequential operation: 668914
# Processing file: File_138...
# Minimum segment length for File_138 in Sequential operation: 669134
# Processing file: File_139...
# Minimum segment length for File_139 in Sequential operation: 669010
# Processing file: File_140...
# Minimum segment length for File_140 in Sequential operation: 669177
# Processing file: File_141...
# Minimum segment length for File_141 in Sequential operation: 669176
# Processing file: File_142...
# Minimum segment length for File_142 in Sequential operation: 668794
# Processing file: File_143...
# Minimum segment length for File_143 in Sequential operation: 668974
# Processing file: File_144...
# Minimum segment length for File_144 in Sequential operation: 669658
# Processing Simultaneous data
# Processing file: File_10...
# Minimum segment length for File_10 in Simultaneous operation: 427764
# Processing file: File_11...
# Minimum segment length for File_11 in Simultaneous operation: 428113
# Processing file: File_12...
# Minimum segment length for File_12 in Simultaneous operation: 428419
# Processing file: File_13...
# Minimum segment length for File_13 in Simultaneous operation: 427551
# Processing file: File_14...
# Minimum segment length for File_14 in Simultaneous operation: 427748
# Processing file: File_15...
# Minimum segment length for File_15 in Simultaneous operation: 426735
# Processing file: File_16...
# Minimum segment length for File_16 in Simultaneous operation: 429024
# Processing file: File_17...
# Minimum segment length for File_17 in Simultaneous operation: 427615
# Processing file: File_18...
# Minimum segment length for File_18 in Simultaneous operation: 429017
# Processing file: File_19...
# Minimum segment length for File_19 in Simultaneous operation: 427689
# Processing file: File_30...
# Minimum segment length for File_30 in Simultaneous operation: 427601
# Processing file: File_31...
# Minimum segment length for File_31 in Simultaneous operation: 427181
# Processing file: File_32...
# Minimum segment length for File_32 in Simultaneous operation: 429105
# Processing file: File_33...
# Minimum segment length for File_33 in Simultaneous operation: 426558
# Processing file: File_34...
# Minimum segment length for File_34 in Simultaneous operation: 428778
# Processing file: File_35...
# Minimum segment length for File_35 in Simultaneous operation: 427686
# Processing file: File_36...
# Minimum segment length for File_36 in Simultaneous operation: 427659
# Processing file: File_37...
# Minimum segment length for File_37 in Simultaneous operation: 427634
# Processing file: File_38...
# Minimum segment length for File_38 in Simultaneous operation: 428009
# Processing file: File_39...
# Minimum segment length for File_39 in Simultaneous operation: 427796
# Processing file: File_55...
# Minimum segment length for File_55 in Simultaneous operation: 402003
# Processing file: File_56...
# Minimum segment length for File_56 in Simultaneous operation: 403996
# Processing file: File_57...
# Minimum segment length for File_57 in Simultaneous operation: 403249
# Processing file: File_58...
# Minimum segment length for File_58 in Simultaneous operation: 404051
# Processing file: File_59...
# Minimum segment length for File_59 in Simultaneous operation: 402368
# Processing file: File_60...
# Minimum segment length for File_60 in Simultaneous operation: 404637
# Processing file: File_61...
# Minimum segment length for File_61 in Simultaneous operation: 403706
# Processing file: File_62...
# Minimum segment length for File_62 in Simultaneous operation: 404937
# Processing file: File_63...
# Minimum segment length for File_63 in Simultaneous operation: 401770
# Processing file: File_64...
# Minimum segment length for File_64 in Simultaneous operation: 404231
# Processing file: File_65...
# Minimum segment length for File_65 in Simultaneous operation: 402354
# Processing file: File_66...
# Minimum segment length for File_66 in Simultaneous operation: 404862
# Processing file: File_67...
# Minimum segment length for File_67 in Simultaneous operation: 402663
# Processing file: File_68...
# Minimum segment length for File_68 in Simultaneous operation: 403392
# Processing file: File_69...
# Minimum segment length for File_69 in Simultaneous operation: 403235
# Processing file: File_85...
# Minimum segment length for File_85 in Simultaneous operation: 668799
# Processing file: File_86...
# Minimum segment length for File_86 in Simultaneous operation: 671095
# Processing file: File_87...
# Minimum segment length for File_87 in Simultaneous operation: 671140
# Processing file: File_88...
# Minimum segment length for File_88 in Simultaneous operation: 671009
# Processing file: File_89...
# Minimum segment length for File_89 in Simultaneous operation: 671058
# Processing file: File_90...
# Minimum segment length for File_90 in Simultaneous operation: 670469
# Processing file: File_91...
# Minimum segment length for File_91 in Simultaneous operation: 670426
# Processing file: File_92...
# Minimum segment length for File_92 in Simultaneous operation: 670666
# Processing file: File_93...
# Minimum segment length for File_93 in Simultaneous operation: 670377
# Processing file: File_94...
# Minimum segment length for File_94 in Simultaneous operation: 671997
# Processing file: File_95...
# Minimum segment length for File_95 in Simultaneous operation: 670781
# Processing file: File_96...
# Minimum segment length for File_96 in Simultaneous operation: 670208
# Processing file: File_97...
# Minimum segment length for File_97 in Simultaneous operation: 671144
# Processing file: File_98...
# Minimum segment length for File_98 in Simultaneous operation: 671244
# Processing file: File_99...
# Minimum segment length for File_99 in Simultaneous operation: 671811
# Processing file: File_115...
# Minimum segment length for File_115 in Simultaneous operation: 669774
# Processing file: File_116...
# Minimum segment length for File_116 in Simultaneous operation: 669046
# Processing file: File_117...
# Minimum segment length for File_117 in Simultaneous operation: 669442
# Processing file: File_118...
# Minimum segment length for File_118 in Simultaneous operation: 670333
# Processing file: File_119...
# Minimum segment length for File_119 in Simultaneous operation: 670032
# Processing file: File_120...
# Minimum segment length for File_120 in Simultaneous operation: 670432
# Processing file: File_121...
# Minimum segment length for File_121 in Simultaneous operation: 670009
# Processing file: File_122...
# Minimum segment length for File_122 in Simultaneous operation: 670809
# Processing file: File_123...
# Minimum segment length for File_123 in Simultaneous operation: 669890
# Processing file: File_124...
# Minimum segment length for File_124 in Simultaneous operation: 669650
# Processing file: File_125...
# Minimum segment length for File_125 in Simultaneous operation: 670527
# Processing file: File_126...
# Minimum segment length for File_126 in Simultaneous operation: 670722
# Processing file: File_127...
# Minimum segment length for File_127 in Simultaneous operation: 669974
# Processing file: File_128...
# Minimum segment length for File_128 in Simultaneous operation: 669085
# Processing file: File_129...
# Minimum segment length for File_129 in Simultaneous operation: 669994
# Processing file: File_145...
# Minimum segment length for File_145 in Simultaneous operation: 671085
# Processing file: File_146...
# Minimum segment length for File_146 in Simultaneous operation: 672272
# Processing file: File_147...
# Minimum segment length for File_147 in Simultaneous operation: 671860
# Processing file: File_148...
# Minimum segment length for File_148 in Simultaneous operation: 671943
# Processing file: File_149...
# Minimum segment length for File_149 in Simultaneous operation: 672573
# Processing file: File_150...
# Minimum segment length for File_150 in Simultaneous operation: 671672
# Processing file: File_151...
# Minimum segment length for File_151 in Simultaneous operation: 671850
# Processing file: File_152...
# Minimum segment length for File_152 in Simultaneous operation: 671183
# Processing file: File_153...
# Minimum segment length for File_153 in Simultaneous operation: 672504
# Processing file: File_154...
# Minimum segment length for File_154 in Simultaneous operation: 672202
# Processing file: File_155...
# Minimum segment length for File_155 in Simultaneous operation: 671443
# Processing file: File_156...
# Minimum segment length for File_156 in Simultaneous operation: 671704
# Processing file: File_157...
# Minimum segment length for File_157 in Simultaneous operation: 672743
# Processing file: File_158...
# Minimum segment length for File_158 in Simultaneous operation: 672127
# Processing file: File_159...
# Minimum segment length for File_159 in Simultaneous operation: 671722
# Global minimum segment length across all operations: 399390

# %%
import torch

# Given conditions
num_channels = 3  # The number of channels is always 3
win_len = 5000

how_many = global_min_length//win_len

# Initialize tensor with fixed dimensions
sim_tensor = torch.zeros(len(simultaneous_dict)*how_many, num_channels, win_len)

sim_file_names = list(simultaneous_dict.keys())
file_names = []

for file_name in sim_file_names:
    file_names.extend([file_name] * how_many)

# Function to trim or pad segments
def process_segment(segment, target_length):
    if len(segment) >= target_length:
        return segment[:target_length]
    else:
        # Example of padding, assuming segments are lists; adjust based on actual data type
        print('-----'*20)
        return segment + [0] * (target_length - len(segment))


current_tensor_index = 0  # Initialize an index to keep track of the current position in sim_tensor

offset = 0
for i, (file_name, file_data) in enumerate(simultaneous_dict.items()):
    for j, (channel_name, channel_data) in enumerate(file_data['channels'].items()):
        processed_segment = process_segment(channel_data['segment'][0], global_min_length)
        
        # Slice every channel segment into subsegments
        for k in range(how_many):
            start_idx = k * win_len
            end_idx = start_idx + win_len
            subsegment = processed_segment[start_idx:end_idx]
            
            # Assign the subsegment correctly to sim_tensor
            if len(subsegment) != win_len:  
                print('Oh, no!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!') #Throw an error instead
                
            sim_tensor[offset+k, j, :] = torch.tensor(subsegment, dtype=torch.float32).view(1, 1, -1)
    offset += how_many


# Define mode descriptions with repetition for each how_many times
mode_descriptions = []

for _, file_data in simultaneous_dict.items():
    mode_tuple = (file_data['Cube 1 Mode'], file_data['Cube 2 Mode'])
    mode_descriptions.extend([mode_tuple] * how_many)

# %%
sim_tensor.shape
# Out:
# torch.Size([6320, 3, 5000])

# %%
len(file_names), len(mode_descriptions)
# Out:
# (6320, 6320)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import random

# Extract 30 random indexes from 0 to the size of sim_tensor's first dimension
max_idx = sim_tensor.shape[0]  # Adjusted to the actual size of sim_tensor
random_indexes = random.sample(range(max_idx), 30)

# Channel names based on the given descriptions
channel_names = {
    0: "Flat response microphone (front)",
    1: "Flat response microphone (rear)",
    2: "Resonant microphone"
}

# Sampling frequency for the time vector calculation
Fs = 200000  # 200kHz

# Iterate over the selected random indexes
for idx in random_indexes:
    sim_data = sim_tensor[idx]
    file_name_sim = file_names[idx]
    mode_desc = mode_descriptions[idx]

    # Number of samples in each signal
    N = sim_data.shape[-1]  # Using the last dimension as the number of samples
    time_vector = np.linspace(0, N / Fs, N, endpoint=False)  # Time vector for plotting
    
    # Plotting
    fig, axs = plt.subplots(3, 1, figsize=(10, 7))  # 3 channels, 1 column for sim
    fig.suptitle(f"Sim: {file_name_sim}, Modes: {mode_desc}")
    
    for channel_idx in range(3):  
        # Plot simultaneous data
        axs[channel_idx].plot(time_vector, sim_data[channel_idx, :].numpy(), label=f"Sim Channel {channel_idx+1}")

        # Set titles and labels
        axs[channel_idx].set_title(f"Simultaneous - {channel_names[channel_idx]}")
        axs[channel_idx].set_xlabel("Time (s)")
        axs[channel_idx].set_ylabel("Amplitude (V)")
        axs[channel_idx].legend()
    
    # Adjust layout
    plt.tight_layout()
    plt.show()

# %%
# Packaging the data into a dictionary
data_package = {
    "sim_tensor": sim_tensor,
    "file_names": file_names,
    "mode_descriptions": mode_descriptions,
}

import os
import pickle

data_folder = "./Data"
os.makedirs(data_folder, exist_ok=True)

with open(os.path.join(data_folder, "pytorch_database_short_TEST.pkl"), "wb") as f:
    pickle.dump(data_package, f)
