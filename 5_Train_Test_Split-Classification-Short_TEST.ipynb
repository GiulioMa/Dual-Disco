# %%
import os
import pickle

data_folder = "./Data"
file_path = os.path.join(data_folder, "pytorch_database_short_TEST.pkl")

with open(file_path, "rb") as f:
    loaded_data = pickle.load(f)

# %%
loaded_data.keys()
# Out:
# dict_keys(['sim_tensor', 'file_names', 'mode_descriptions'])

# %%
len(loaded_data['mode_descriptions'])
# Out:
# 6320

# %%
# Modes for testing
test_modes = [
    ('Conduction 4', 'Conduction 4'),
    ('Conduction 4', 'Keyhole 4'),
    ('Keyhole 4', 'Conduction 4'),
    ('Keyhole 4', 'Keyhole 4'),
]

# %%
mode_descriptions = loaded_data['mode_descriptions']
# Identify indexes for test data
test_indexes = [i for i, mode in enumerate(mode_descriptions) if mode in test_modes]

len(test_indexes), len(test_indexes)/len(mode_descriptions)
# Out:
# (4740, 0.75)

# %%
# Identify indexes for train data
total_indexes = set(range(len(mode_descriptions)))
train_indexes = list(total_indexes - set(test_indexes))

# Function to extract sub-tensors based on indexes
def extract_sub_tensors(tensor, indexes):
    return tensor[indexes]

# Allocate data to train and test dictionaries
train_data = {
    "sim_tensor": extract_sub_tensors(loaded_data["sim_tensor"], train_indexes),
    "file_names": [loaded_data["file_names"][i] for i in train_indexes],
    "mode_descriptions": [loaded_data["mode_descriptions"][i] for i in train_indexes],
}

test_data = {
    "sim_tensor": extract_sub_tensors(loaded_data["sim_tensor"], test_indexes),
    "file_names": [loaded_data["file_names"][i] for i in test_indexes],
    "mode_descriptions": [loaded_data["mode_descriptions"][i] for i in test_indexes],
}

# %%
# Function to print file names and modes for a given dataset
def print_file_info(dataset, dataset_name):
    print(f"Files in {dataset_name}:")
    for file_name, mode in zip(dataset["file_names"], dataset["mode_descriptions"]):
        print(f"File Name: {file_name}, Mode: {mode}")
    print("\n")

# %%
# Loop over all files in the train set
print_file_info(train_data, "Train Data")
# Out:
# Files in Train Data:
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_10, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_11, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_12, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_13, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_14, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_15, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_16, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_17, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_18, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_19, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_30, Mode: ('Conduction 2', 'Conduction 2')
# ...
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_36, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_37, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_38, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_39, Mode: ('Conduction 2', 'Conduction 2')

# %%
# Loop over all files in the test set
print_file_info(test_data, "Test Data")
# Out:
# Files in Test Data:
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_55, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_56, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_57, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_58, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_59, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_60, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_61, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_62, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_63, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_64, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_65, Mode: ('Conduction 4', 'Conduction 4')
# ...
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_156, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_157, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_158, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_159, Mode: ('Keyhole 4', 'Keyhole 4')

# %%
import torch

torch.save(train_data, './Data/train_classification_short_TEST')
torch.save(test_data, './Data/test_classification_short_TEST')
