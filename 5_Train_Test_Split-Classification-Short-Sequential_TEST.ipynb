# %%
import os
import pickle

data_folder = "./Data"
file_path = os.path.join(data_folder, "pytorch_database_short_seq_TEST.pkl")

with open(file_path, "rb") as f:
    loaded_data = pickle.load(f)

# %%
loaded_data.keys()
# Out:
# dict_keys(['sim_tensor', 'file_names', 'mode_descriptions'])

# %%
len(loaded_data['mode_descriptions'])
# Out:
# 6320

# %%
# Modes for testing
test_modes = [
    ('Conduction 4', 'Conduction 4'),
    ('Conduction 4', 'Keyhole 4'),
    ('Keyhole 4', 'Conduction 4'),
    ('Keyhole 4', 'Keyhole 4'),
]

# %%
mode_descriptions = loaded_data['mode_descriptions']
# Identify indexes for test data
test_indexes = [i for i, mode in enumerate(mode_descriptions) if mode in test_modes]

len(test_indexes), len(test_indexes)/len(mode_descriptions)
# Out:
# (4740, 0.75)

# %%
# Identify indexes for train data
total_indexes = set(range(len(mode_descriptions)))
train_indexes = list(total_indexes - set(test_indexes))

# Function to extract sub-tensors based on indexes
def extract_sub_tensors(tensor, indexes):
    return tensor[indexes]

# Allocate data to train and test dictionaries
train_data = {
    "seq_tensor": extract_sub_tensors(loaded_data["sim_tensor"], train_indexes),
    "file_names": [loaded_data["file_names"][i] for i in train_indexes],
    "mode_descriptions": [loaded_data["mode_descriptions"][i] for i in train_indexes],
}

test_data = {
    "seq_tensor": extract_sub_tensors(loaded_data["sim_tensor"], test_indexes),
    "file_names": [loaded_data["file_names"][i] for i in test_indexes],
    "mode_descriptions": [loaded_data["mode_descriptions"][i] for i in test_indexes],
}

# %%
# Function to print file names and modes for a given dataset
def print_file_info(dataset, dataset_name):
    print(f"Files in {dataset_name}:")
    for file_name, mode in zip(dataset["file_names"], dataset["mode_descriptions"]):
        print(f"File Name: {file_name}, Mode: {mode}")
    print("\n")

# %%
# Loop over all files in the train set
print_file_info(train_data, "Train Data")
# Out:
# Files in Train Data:
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_0, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_1, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_2, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_3, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_4, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_5, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_6, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_7, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_8, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_9, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_20, Mode: ('Conduction 2', 'Conduction 2')
# ...
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_26, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_27, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_28, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')
# File Name: File_29, Mode: ('Conduction 2', 'Conduction 2')

# %%
# Loop over all files in the test set
print_file_info(test_data, "Test Data")
# Out:
# Files in Test Data:
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_40, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_41, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_42, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_43, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_44, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_45, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_46, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_47, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_48, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_49, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# File Name: File_50, Mode: ('Conduction 4', 'Conduction 4')
# ...
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_141, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_142, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_143, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')
# File Name: File_144, Mode: ('Keyhole 4', 'Keyhole 4')

# %%
import torch

torch.save(train_data, './Data/train_classification_short_seq_TEST')
torch.save(test_data, './Data/test_classification_short_seq_TEST')
